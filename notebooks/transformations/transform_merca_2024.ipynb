# %%
import pandas as pd
import numpy as np
import csv
import re

from unidecode import unidecode #para los acentos

#Deberia revisar lo de Counter que lo uso bastante y no conoxco muy bien la libreria
from collections import Counter

# %%
def export_to_csv(data_frame, file_name):
    """
    Export a DataFrame to a CSV file.

    Parameters:
        - data_frame: pandas DataFrame
        - file_name: str, name of the CSV file (without the extension)
    """
    #print date stamp - datetime.datetime.now()
    
    #t_stamp = str(datetime.datetime.now()).split(".")[0].replace(" ","_")
    
    file_path = f"{file_name}.csv"
    
    data_frame.to_csv(file_path, index=False)
    print(f"DataFrame successfully exported to {file_path}")

# %%
df1 = pd.read_csv("../scraping/scrape_mercadona/mercadona-01.csv")
df2 = pd.read_csv("../scraping/scrape_mercadona/mercadona-02.csv")
df3 = pd.read_csv("../scraping/scrape_mercadona/mercadona-03.csv")
df4 = pd.read_csv("../scraping/scrape_mercadona/mercadona-04.csv")
df5 = pd.read_csv("../scraping/scrape_mercadona/mercadona-05.csv")
df6 = pd.read_csv("../scraping/scrape_mercadona/mercadona-06.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6])

# %%
for i in df["unidades"]:
    print(i)
# Out:
# Botella 1 L
# Garrafa 3 L
# Botella 1 L
# Botella 750 ml
# Botella 1 L
# Garrafa 3 L
# Botella 1 L
# Garrafa 3 L
# Garrafa 3 L
# Spray 200 ml
# Botella 500 ml
# Garrafa 5 L
# Botella 1 L
# Bote 450 ml
# Botella 1 L
# Botella 1 L
# Botella 280 ml
# Botella 250 g
# Botella 250 ml
# Botella 750 ml
# Botella 1 L
# Botella 300 g
# 15 monodosis x 10 ml
# Botella 160 ml
# Botella 500 ml
# Botella 500 ml
# Paquete 1 kg
# Bote 250 g
# Paquete 1 kg
# Paquete 1 kg
# Paquete 1 kg
# Bote 300 g
# Bote 125 g
# Paquete 2 kg
# Bote 130 g
# Bote 250 g
# Bote 250 g
# Bote 750 g
# Bote 250 g
# Bote 25 g
# Bote 18 g
# Paquete 12 g
# Bote 25 g
# Bote 20 g
# Bote 40 g
# Bote 24 g
# Bote 18 g
# Bote 12 g
# Bote 74 g
# Bote 85 g
# Bote 56 g
# Bote 75 g
# Bote 75 g
# Paquete 4 sobres (0,4 g)
# Paquete 3 usos (0,38 g)
# Bote 60 g
# Bote 70 g
# Bote 65 g
# Bote 70 g
# Bote 50 g
# Bote 70 g
# Bote 115 g
# Bote 150 g
# Bote 52 g
# Bote 19 g
# Bote 58 g
# Bote 56 g
# Bote 57 g
# Bote 58 g
# Bote 60 g
# Bote 27 g
# Bote 55 g
# Bote 60 g
# Bote 49 g
# Bote 130 g
# Bote 42 g
# Bote 70 g
# Bote 25 g
# Sobre 17 g
# Sobre 30 g
# Sobre 24 g
# Sobre 57 g
# Caja 5 sobres (20 g)
# Sobre 40 g
# Bote 76 g
# Bote 45 g
# Tarro 500 ml
# Tarro 240 ml
# Bote 460 ml
# 12 sobres x 20 ml
# Tarro 450 ml
# Tarro 225 ml
# Tarro 425 ml
# Tarro 210 ml
# Bote 430 ml
# Bote 500 ml
# Tarro 425 ml
# Tarro 500 ml
# Bote 460 ml
# Bote 600 g
# Paquete 12 sobres (240 g)
# Bote 650 g
# Bote 600 g
330 ml
# Lata 330 ml
# Botella 2 L
# 6 latas x 330 ml
# Lata 330 ml
# Botella 2 L
# 6 latas x 330 ml
# Lata 330 ml
# 8 latas x 330 ml
# Lata 330 ml
# Botella 2 L
# 8 latas x 330 ml
# Lata 330 ml
# Botella 2 L
# 9 latas x 330 ml
# Lata 330 ml
# Botella 2 L
# 6 latas x 330 ml
# Lata 330 ml
# Botella 2 L
# 2 botellas x 2 L
# Botella 2 L
# 9 latas x 330 ml
# Lata 330 ml
# Botella 2 L
# Lata 330 ml
# Botella 2 L
# 6 latas x 330 ml
# Lata 330 ml
# Botella 2 L
# 6 latas x 330 ml
# Lata 330 ml
# 8 latas x 330 ml
# Lata 330 ml
# Botella 1 L
# 6 botellines x 200 ml
# Botellín 200 ml
# 6 latas x 330 ml
# Lata 330 ml
# 8 latas x 330 ml
# Lata 330 ml
# 8 latas x 250 ml
# Lata 250 ml
# 8 latas x 330 ml
# Lata 330 ml
# Lata 330 ml
# 8 latas x 330 ml
# Lata 330 ml
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# Caja 12 sobres (36 g)
# Caja 12 sobres (36 g)
# Botella 1,5 L
# 6 latas x 330 ml
# Lata 330 ml
# Botella 1,5 L
# Botella 2 L
# Botella 1,5 L
# Botella 2 L
# 4 botellas x 330 ml
# Botella 2 L
# Botella 1,5 L
# Botella 1,25 L
# Botella 1,5 L
# Botella 2 L
# Brick 1 L
# Botella 2 L
# Botella 2 L
# 4 botellas x 330 ml
# 3 botes x 150 g
# 3 botes x 50 g
# Bote 350 g (150 g escurrido)
# Tarro 835 g (400 g escurrido)
# Bote 350 g (150 g escurrido)
# 3 botes x 50 g
# Tarro 980 g (600 g escurrido)
# Tarro 835 g (500 g escurrido)
# Bote 350 g (150 g escurrido)
# Bote 1,46 kg (600 g escurrido)
# 3 paquetes x 75 g
# Tarro 935 g (550 g escurrido)
# Tarro 835 g (500 g escurrido)
# Tarro 420 g (200 g escurrido)
# Tarro 350 g (185 g escurrido)
# Bote 350 g (150 g escurrido)
# Bote 1,33 kg (830 g escurrido)
# Bote 350 g (150 g escurrido)
# Tarro 935 g (530 g escurrido)
# Tarro 430 g (250 g escurrido)
# Bote 815 g (450 g escurrido)
# Tarro 370 g (210 g escurrido)
# Bote 350 g (150 g escurrido)
# Tarro 710 g (350 g escurrido)
# Bote 350 g (150 g escurrido)
# Tarro 200 g
# Bote 350 g (185 g escurrido)
# Tarro 210 g
# 3 botes x 50 g
# Tarro 345 g (160 g escurrido)
# Tarro 345 g (160 g escurrido)
# Tarro 670 g (370 g escurrido)
# Tarro 420 g (230 g escurrido)
# Tarro 690 g (440 g escurrido)
# Tarro 135 g (80 g escurrido)
# Tarro 670 g (370 g escurrido)
# Tarro 420 g (250 g escurrido)
# Tarro 530 g (290 g escurrido)
# Tarro 350 g (190 g escurrido)
# Tarro 285 g (125 g escurrido)
# Tarro 345 g (235 g escurrido)
# Bote 800 g (350 g escurrido)
# Tarro 135 g (60 g escurrido)
# Tarro 285 g (125 g escurrido)
# Tarro 670 g (360 g escurrido)
# Tarro 425 g (230 g escurrido)
# Paquete 200 g
# Paquete 200 g
# Paquete 250 g
# Paquete 200 g
# Paquete 250 g
# Paquete 250 g
# Paquete 200 g
# Paquete 200 g
# Paquete 3 ud. (270 g)
# Paquete 200 g
# Paquete 200 g
# Paquete 200 g
# Paquete 250 g
# Paquete 170 g
# Paquete 200 g
# Paquete 400 g
# Paquete 200 g
# Paquete 250 g
# Paquete 150 g
# 2 paquetes x 150 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# Bote 165 g
# Paquete 150 g
# Bote 165 g
# Paquete 130 g
# Paquete 130 g
# Paquete 195 g
# Paquete 130 g
# Paquete 130 g
# Paquete 130 g
# Paquete 130 g
# Paquete 150 g
# Paquete 75 g
# Paquete 150 g
# Paquete 130 g
# Paquete 150 g
# Paquete 80 g
# Paquete 100 g
# Paquete 100 g
# Bote 350 g
# Paquete 80 g
# Paquete 200 g
# Paquete 80 g
# Paquete 140 g
# Paquete 100 g
# Paquete 80 g
# Paquete 200 g
# Paquete 120 g
# Paquete 50 g
# Paquete 80 g
# Bote 300 g
# Paquete 75 g
# Paquete 75 g
# 10 paquetes x 6 g
# Paquete 20 g
# Paquete 120 g
# Paquete 120 g
# Paquete 100 g
# Paquete 125 g
# Paquete 100 g
# Paquete 100 g
# Paquete 100 g
# Paquete 100 g
# Paquete 1 kg
# Paquete 1 kg
# 2 vasitos x 125 g
# 2 vasitos x 125 g
# Paquete 1 kg
# 2 vasitos x 125 g
# 2 vasitos x 125 g
# Paquete 1 kg
# Paquete 1 kg
# Paquete 1 kg
# Caja 1 kg
# Paquete 1 kg
# Paquete 500 g
# Paquete 200 g
# Paquete 1 kg
# Paquete 1 kg
# Tarro 570 g (400 g escurrido)
# Tarro 295 g (210 g escurrido)
# Tarro 570 g (400 g escurrido)
# Paquete 1 kg
# Paquete 1 kg
# Paquete 1 kg
# Tarro 570 g (400 g escurrido)
# Tarro 295 g (210 g escurrido)
# Tarro 570 g (400 g escurrido)
# Tarro 570 g (400 g escurrido)
# Paquete 1 kg
# Tarro 295 g (210 g escurrido)
# Paquete 1 kg
# Paquete 1 kg
# Tarro 570 g (350 g escurrido)
# Paquete 1 kg
# Paquete 1 kg
# Tarro 570 g (400 g escurrido)
# Tarro 295 g (210 g escurrido)
# Paquete 250 g
# Paquete 1 kg
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Caja 225 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 1 kg
# Paquete 500 g
# Paquete 500 g
# Paquete 1 kg
# Paquete 500 g
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 1 kg
# Paquete 500 g
# Paquete 500 g
# Paquete 250 g
# Paquete 250 g
# Bandeja 250 g
# Bandeja 250 g
# Paquete 250 g
# Paquete 500 g
# Bandeja 250 g
# Bandeja 250 g
# Bandeja 250 g
# Bandeja 250 g
# Paquete 250 g
# Paquete 400 g
# Bandeja 250 g
# Bandeja 250 g
# Caja 18 placas (200 g)
# Caja 12 placas (80 g)
# Caja 20 placas (125 g)
# Vaso 93 g
# 3 vasos x 60 g
# Vaso 60 g
# Paquete 71 g
# Vaso 80 g
# Paquete 90 g
# Vaso 65 g
# Vaso 65 g
# Paquete 1 kg
# Paquete 1 kg
# Caja 50 sticks (350 g)
# Paquete 1 kg
# Caja 50 sobres (350 g)
# Paquete 500 g
# Bote 500 g
# Bote 150 ml
# Bote 850 pastillas (52 g)
# Caja 60 sobres (60 g)
# Bote 350 g
# Bote 150 ml
# Bote 200 g
# Bote 175 pastillas (9 g)
# Caja 54 sobres (54 g)
# Bote 200 g
# Paquete 32 chicles (45 g)
# Bote 70 chicles (100 g)
# Paquete 32 chicles (45 g)
# Bote 70 chicles (100 g)
# Paquete 12 chicles (31 g)
# Paquete 32 chicles (45 g)
# Paquete 32 chicles (45 g)
# Bote 70 chicles (100 g)
# Paquete 32 chicles (45 g)
# Paquete 32 chicles (45 g)
# Paquete 12 chicles (31 g)
# Paquete 25 chicles (100 g)
# Paquete 32 chicles (45 g)
# Paquete 100 g
# Paquete 90 g
# Paquete 90 g
# Paquete 90 g
# Paquete 150 g
# 4 paquetes x 32 g
# Paquete 150 g
# 4 paquetes x 32 g
# Paquete 300 g
# Paquete 125 g
# Paquete 12 ud. (144 g)
# Paquete 150 g
# Paquete 90 g
# Paquete 100 g
# Paquete 7 ud. (105 g)
# Paquete 150 g
# Paquete 300 g
# Tableta 100 g
# Tableta 200 g
# Paquete 200 g
# Tableta 100 g
# Tableta 100 g
# Tableta 100 g
# Tableta 200 g
# Tableta 300 g
# Tableta 250 g
# Tableta 140 g
# Tableta 150 g
# Caja 200 g
# Paquete 250 g
# Tableta 200 g
# Paquete 200 g
# Tableta 100 g
# Tableta 100 g
# Tableta 200 g
# Tableta 100 g
# Tableta 150 g
# Tableta 95 g
# Tableta 150 g
# Tableta 125 g
# Tableta 100 g
# Tableta 150 g
# Tableta 200 g
# Tableta 250 g
# Tableta 150 g
# Tableta 125 g
# Tableta 100 g
# Tableta 150 g
# Tableta 300 g
# Tableta 150 g
# Tableta 110 g
# Paquete 100 g
# Tableta 200 g
# Tableta 100 g
# Tableta 110 g
# Tableta 100 g
# Tableta 200 g
# Tableta 100 g
# Tableta 100 g
# Paquete 10 ud. (200 g)
# Paquete 16 ud. (200 g)
# Paquete 5 ud. (207,5 g)
# Paquete 3 ud. (141 g)
# Paquete 200 g
# Paquete 250 g
# Paquete 250 g
# Paquete 5 ud. (200 g)
# Paquete 180 g
# Malla 70 g
# 3 ud. x 20 g
# 3 ud. x 20 g
# 50 g
# 25 g
# Paquete 200 g
# Paquete 6 ud. (135 g)
# Paquete 6 ud. (135 g)
# Paquete 6 ud. (216 g)
# 35 g
# Paquete 200 g
# Paquete 150 g
# 120 g
# 120 g
# Paquete 150 g
# 40 g
# 60 g
# 60 g
# Paquete 470 g
# Paquete 150 g
# Caja 22 ud. (200 g)
# Caja 200 g
# Paquete 16 ud. (180 g)
# Caja 16 ud. (216 g)
# Caja 20 ud. (205 g)
# Bote 500 g
# Bote 400 g
# Tarro 350 g
# Tarro 360 g
# Tarro 430 g
# Bote 500 g
# Tarro 360 g
# Tarro 500 g
# Tarro 500 g
# Tarro 400 g
# Paquete 20 ud. (135 g)
# Paquete 200 g
# Paquete 250 g
# Paquete 150 g
# Paquete 100 g
# Caja 320 g
# Paquete 200 g
# Paquete 150 g
# Paquete 300 g
# Paquete 300 g
# Paquete 150 g
# Paquete 100 g
# Paquete 300 g
# Paquete 300 g
# Paquete 300 g
# Paquete 200 g
# Caja 300 g
# Paquete 20 ud. (135 g)
# Paquete 200 g
# Paquete 250 g
# Paquete 150 g
# Paquete 100 g
# Caja 320 g
# Paquete 200 g
# Paquete 150 g
# Paquete 300 g
# Paquete 300 g
# Paquete 150 g
# Paquete 100 g
# Paquete 300 g
# Paquete 300 g
# Paquete 300 g
# Paquete 200 g
# Caja 300 g
# Paquete 300 g
# Paquete 300 g
# Paquete 300 g
# Paquete 200 g
# Paquete 60 g
# Paquete 200 g
# Paquete 4 ud. (75 g)
# Paquete 300 g
# Tarro 400 g
# 10 ud. x 25 g
# Tarro 440 g
# Tarro 330 g
# Tarro 440 g
# 10 ud. x 25 g
# Tarro 350 g
# Tarro 350 g
# Tarro 440 g
# Tarro 440 g
# Tarro 340 g
# Tarro 230 g
# Tarro 340 g
# Tarro 340 g
# Tarro 1 kg
# Bote 500 g
# Bote 500 g
# Bote 500 g
# Tarro 300 g
# Bote 500 g
# Tarro 190 g
# Tarro 380 g
# Tarro 380 g
# Tarro 380 g
# Tarrito 235 g
# Tarrito 235 g
# Tarrito 235 g
# Tarrito 235 g
# 2 tarritos x 190 g
# Tarrito 235 g
# Tarrito 235 g
# Tarrito 235 g
# 2 tarritos x 190 g
# 2 tarritos x 190 g
# 1 ud. (120 g)
# 1 ud. (120 g)
# 1 ud. (120 g)
# 4 tarritos x 130 g
# 4 tarritos x 130 g
# 4 tarritos x 130 g
# 4 tarritos x 130 g
# 1 ud. (120 g)
# 1 ud. (120 g)
# 4 tarritos x 130 g
# 1 ud. (100 g)
# 1 ud. (100 g)
# 4 ud. x 100 g
# Caja 4 ud. (360 g)
# 4 ud. x 100 g
# 4 ud. x 100 g
# 1 ud. (100 g)
# 6 bricks x 1 L
# Brick 1 L
# 6 bricks x 1 L
# Brick 1 L
# 6 bricks x 1 L
# Brick 1 L
# 6 mini bricks x 200 ml
# 3 mini bricks x 200 ml
# 6 mini bricks x 200 ml
# 6 bricks x 1 L
# Brick 1 L
# Bote 800 g
# Bote 800 g
# Bote 800 g
# Bote 800 g
# Bote 800 g
# Caja 725 g
# Caja 725 g
# Caja 725 g
# Caja 410 g
# Caja 410 g
# Caja 220 g
# Caja 340 g
# 1 ud.
# 1 ud.
# Paquete 2 ud.
# Paquete 2 ud.
# Paquete 1 ud.
# Bote 500 ml
# Paquete 1 ud.
# Paquete 1 ud.
# Paquete 1 ud.
# Bote 600 ml
# Bote 600 ml
# Bote 600 ml
# Tubo 100 ml
# Botella 500 ml
# Bote 600 ml
# Bote 200 ml
# Botella 500 ml
# Bote 600 ml
# Bote 100 ml
# Caja 30 ud.
# Paquete 100 ud.
# Paquete 1 ud.
# Paquete 10 ud.
# Paquete 1 ud.
# Paquete 10 ud.
# Bote 200 g
# Caja 60 ud.
# 3 paquetes x 80 ud.
# Paquete 80 ud.
# Paquete 24 ud.
# Paquete 80 ud.
# Paquete 20 ud.
# Paquete 60 ud.
# Paquete 60 ud.
# Paquete 44 ud.
# Paquete 30 ud.
# Paquete 42 ud.
# Paquete 58 ud.
# Paquete 56 ud.
# 3 paquetes x 36 ud.
# Paquete 36 ud.
# 3 paquetes x 34 ud.
# Paquete 34 ud.
# Paquete 58 ud.
# 3 paquetes x 30 ud.
# Paquete 30 ud.
# Paquete 54 ud.
# Paquete 22 ud.
# Paquete 36 ud.
# Paquete 20 ud.
# Paquete 6 ud.
# Paquete 24 ud.
# Paquete 22 ud.
# Paquete 16 ud.
# Paquete 13 ud.
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 6 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 6 latas x 330 ml
# Lata 330 ml
# 6 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 9 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 6 latas x 330 ml
# Lata 330 ml
# 6 botellas x 1 L
# Botella 1 L
# 6 botellas x 1 L
# Botella 1 L
# 12 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# Botellín 330 ml
# 6 botellas x 1 L
# Botella 1 L
# 6 botellines x 250 ml
# Botellín 250 ml
# 12 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# Botellín 330 ml
# 12 botellines x 250 ml
# Botellín 250 ml
# 12 botellines x 250 ml
# Botellín 250 ml
# 12 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# Botellín 330 ml
# 12 botellines x 200 ml
# Botellín 200 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# Botellín 330 ml
# 12 botellines x 250 ml
# Botellín 250 ml
# 12 latas x 330 ml
# Lata 330 ml
# 6 botellas x 500 ml
# Botellín 500 ml
# 12 botellines x 200 ml
# Botellín 200 ml
# 6 botellines x 355 ml
# Botellín 355 ml
# 12 latas x 330 ml
# Lata 330 ml
# 6 botellines x 500 ml
# Botellín 500 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# Botellín 330 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# Botella 1 L
# Botella 1 L
# Botella 1 L
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# Botellín 330 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# Botella 1 L
# Botella 1 L
# Botella 1 L
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 750 ml
# 12 botellines x 250 ml
# Botellín 250 ml
# Botella 700 ml
# Botella 750 ml
# Benjamín 200 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Benjamín 200 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# 2 botellas x 1,5 L
# Botella 1,5 L
# Brick 1 L
# 3 mini bricks x 250 ml
# Botella 750 ml
# Brick 1 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 1,5 L
# Botella 750 ml
# Botella 1 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Brick 1 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Garrafa 5 L
# Botella 750 ml
# Botella 750 ml
# Brick 1 L
# Brick 1 L
# Botella 2 L
# Garrafa 5 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Benjamín 187 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Paquete 1 kg
# Bote 390 g
# Bote 325 g
# Bote 760 g
# Bote 383 g
# Paquete 1 kg
# Bote 1 kg
# Bote 480 g
# Caja 2,5 kg
# Bote 450 g
# Caja 2,7 kg
# Bote 500 g
# Caja 6 sobres (108 g)
# Bote 265 g
# Paquete 500 g
# Brick 1 L
# Paquete 400 g
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (106 g)
# Caja 20 cápsulas (110 g)
# Caja 20 cápsulas (104 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (992 g)
# Caja 16 cápsulas (160 g)
# Caja 16 cápsulas (152 g)
# Caja 16 cápsulas (128 g)
# Caja 16 cápsulas (100,8 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (92,8 g)
# Caja 8 cápsulas (186,4 g)
# Caja 16 cápsulas (152 g)
# Caja 16 cápsulas (91,2 g)
# Caja 16 cápsulas (128 g)
# Caja 8 cápsulas (185,6 g)
# Paquete 16 cápsulas (118,4 g)
# Paquete 16 cápsulas (132,8 g)
# Paquete 16 cápsulas (184 g)
# Paquete 16 cápsulas (118,4 g)
# Paquete 16 cápsulas (184 g)
# Paquete 32 dosis (224 g)
# Paquete 32 dosis (224 g)
# Paquete 32 dosis (224 g)
# Paquete 32 dosis (224 g)
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 250 g
# Paquete 250 g
# Paquete 250 g
# Paquete 250 g
# Paquete 250 g
# Caja 250 g
# Caja 250 g
# Caja 250 g
# Paquete 1 kg
# Paquete 1 kg
# Paquete 1 kg
# Paquete 1 kg
# Bote 200 g
# Bote 100 g
# Caja 10 sobres (20 g)
# Tarro 200 g
# Tarro 100 g
# Bote 200 g
# Bote 100 g
# Caja 10 sobres (20 g)
# Tarro 200 g
# Tarro 100 g
# Bote 80 g
# Bote 250 g
# Bote 250 g
# Bote 300 g
# Bote 100 g
# Bote 250 g
# Vaso 250 ml
# Vaso 250 ml
# Vaso 250 ml
# Vaso 250 ml
# Paquete 20 ud. (200 ml)
# Bote 150 g
# Caja 100 filtros
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (40 g)
# Caja 20 bolsitas (40 g)
# Caja 20 bolsitas (40 g)
# Caja 40 bolsitas (116 g)
# Caja 20 bolsitas (30 g)
# Caja 10 sobres (15 g)
# Caja 20 bolsitas (40 g)
# Caja 20 bolsitas (27 g)
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (24 g)
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (26 g)
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (24 g)
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (40 g)
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (40 g)
# Caja 20 bolsitas (30 g)
# Paquete 500 g
# Caja 20 bolsitas (40 g)
# Caja 20 bolsitas (26 g)
# Caja 20 bolsitas (40 g)
# Caja 20 bolsitas (34 g)
# Caja 20 bolsitas (30 g)
# Caja 20 bolsitas (40 g)
# Bandeja 1 kg aprox.
# Bandeja 2 ud. (280 g aprox.)
# Bandeja 330 g aprox.
# 290 g aprox.
# Bandeja 250 g aprox.
# Bandeja 300 g aprox.
# Paquete 250 g
# Bandeja 180 g aprox.
# Bandeja 500 g aprox.
# Bandeja 250 g aprox.
# Paquete 190 g aprox.
# Paquete 250 g
# Bandeja 350 g aprox.
# Bandeja 500 g aprox.
# Bandeja 1 kg aprox.
# Bandeja
# Bandeja 400 g aprox.
# Bandeja 760 g aprox.
# Bandeja 850 g aprox.
# Bandeja 800 g aprox.
# Bandeja 540 g aprox.
# Bandeja 460 g aprox.
# Bandeja 410 g aprox.
# Bandeja 500 g aprox.
# Paquete 300 g aprox.
# Paquete 290 g aprox.
# Bandeja 535 g aprox.
# Bandeja 560 g
# Bandeja 550 g aprox.
# Bandeja 280 g aprox.
# Bandeja 600 g aprox.
# Bandeja 360 g aprox.
# Paquete 220 g
# Bandeja 400 g aprox.
# Bandeja 380 g aprox.
# Bandeja 640 g aprox.
# Bandeja 650 g aprox.
# Bandeja 500 g aprox.
# Paquete 300 g aprox.
# Bandeja 300 g aprox.
# Bandeja 375 g aprox.
# Bandeja 6 ud. (540 g)
# Bandeja 6 ud. (540 g)
# Bandeja 6 ud. (540 g)
# Bandeja 6 ud. (540 g)
# Bandeja 2 ud. (360 g)
# Bandeja 2 ud. (240 g)
# Bandeja 2 ud. (240 g)
# Bandeja 6 ud. (540 g)
# Bandeja 8 ud. (280 g)
# Bandeja 8 ud. (280 g)
# Bandeja 2 ud. (360 g)
# Bandeja 2 ud. (360 g)
# Bandeja 2 ud. (360 g)
# Bandeja 2 ud. (240 g)
# Bandeja 2 ud. (240 g)
# Bandeja 2 ud. (360 g)
# Bandeja 2 ud. (240 g)
# Paquete 2 ud. (240 g)
# Bandeja 500 g
# Bandeja 1 kg
# Bandeja 500 g
# Bandeja 1 kg
# Bandeja 500 g
# Bandeja 1 kg
# Bandeja 500 g
# Bandeja 1 kg
# Bandeja 24 ud. (840 g)
# Bandeja 840 g
# Bandeja 500 g aprox.
# Bandeja 600 g aprox.
# Bandeja 500 g aprox.
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 6 botellines x 330 ml
# Botellín 330 ml
# 6 botellines x 250 ml
# Botellín 250 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# 12 latas x 330 ml
# Lata 330 ml
# Botella 1 L
# Botella 1 L
# Botella 1 L
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 700 ml
# Botella 1 L
# Botella 700 ml
# Botella 750 ml
# 12 botellines x 250 ml
# Botellín 250 ml
# Botella 700 ml
# Botella 750 ml
# Benjamín 200 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Benjamín 200 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# Botella 1,5 L
# 2 botellas x 1,5 L
# Botella 1,5 L
# Brick 1 L
# 3 mini bricks x 250 ml
# Botella 750 ml
# Brick 1 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 1,5 L
# Botella 750 ml
# Botella 1 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Brick 1 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Garrafa 5 L
# Botella 750 ml
# Botella 750 ml
# Brick 1 L
# Brick 1 L
# Botella 2 L
# Garrafa 5 L
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Benjamín 187 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Botella 750 ml
# Paquete 1 kg
# Bote 390 g
# Bote 325 g
# Bote 760 g
# Bote 383 g
# Paquete 1 kg
# Bote 1 kg
# Bote 480 g
# Caja 2,5 kg
# Bote 450 g
# Caja 2,7 kg
# Bote 500 g
# Caja 6 sobres (108 g)
# Bote 265 g
# Paquete 500 g
# Brick 1 L
# Paquete 400 g
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (104 g)
# Caja 20 cápsulas (106 g)
# Caja 20 cápsulas (110 g)
# Caja 20 cápsulas (104 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (992 g)
# Caja 16 cápsulas (160 g)
# Caja 16 cápsulas (152 g)
# Caja 16 cápsulas (128 g)
# Caja 16 cápsulas (100,8 g)
# Caja 16 cápsulas (112 g)
# Caja 16 cápsulas (92,8 g)
# Caja 8 cápsulas (186,4 g)
# Caja 16 cápsulas (152 g)
# Caja 16 cápsulas (91,2 g)
# Caja 16 cápsulas (128 g)
# Caja 8 cápsulas (185,6 g)
# Paquete 16 cápsulas (118,4 g)
# Paquete 16 cápsulas (132,8 g)
# Paquete 16 cápsulas (184 g)
# Paquete 16 cápsulas (118,4 g)
# Paquete 16 cápsulas (184 g)
# Paquete 32 dosis (224 g)
# Paquete 32 dosis (224 g)
# Paquete 32 dosis (224 g)
# Paquete 32 dosis (224 g)
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 250 g
# Paquete 500 g
# Paquete 250 g
# Paquete
# Bandeja 600 g aprox.
# Bandeja 600 g aprox.
# Bandeja 500 g aprox.
# Bandeja 500 g aprox.
# Bandeja 580 g aprox.
# Bandeja 370 g
# Bandeja 600 g aprox.
# Bandeja 600 g aprox.
# Bandeja 290 g aprox.
# Paquete 220 g aprox.
# Paquete 500 g
# Paquete 500 g
# Bandeja 500 g aprox.
# Bandeja 500 g aprox.
# Bandeja 340 g aprox.
# Bandeja 370 g
# Bandeja 450 g aprox.
# Bandeja 465 g aprox.
# Bandeja 380 g aprox.
# Bandeja 400 g aprox.
# Caja 500 g
# Caja 5 bolsitas (175 g)
# Paquete 500 g
# Caja 400 g
# Caja 500 g
# Caja 500 g
# Caja 500 g
# Caja 420 g
# Caja 500 g
# Caja 375 g
# Paquete 400 g
# Caja 500 g
# Caja 450 g
# Paquete 500 g
# Caja 500 g
# Paquete 400 g
# Caja 625 g
# Paquete 500 g
# Paquete 500 g
# Caja 375 g
# Caja 425 g
# Paquete 500 g
# Paquete 500 g
# Caja 375 g
# Paquete 500 g
# Paquete 400 g
# Caja 500 g
# Paquete 1 kg
# Paquete 500 g
# Paquete 250 g
# Paquete 400 g
# Paquete 375 g
# Caja 400 g
# Paquete 400 g
# Caja 6 barritas (120 g)
# Caja 6 barritas (127 g)
# Caja 6 barritas (138 g)
# Caja 6 barritas (150 g)
# Caja 4 barritas (120 g)
# Caja 3 barritas (120 g)
# Caja 3 barritas (180 g)
# Caja 6 barritas (120 g)
# Caja 6 paquetes (252 g)
# Caja 5 barritas (125 g)
# Caja 3 barritas (90 g)
# Caja 4 barritas (138 g)
# Paquete 4 ud. (800 g)
# Caja 10 paquetes (411 g)
# Caja 3 paquetes (570 g)
# Paquete 3 ud. (600 g)
# Paquete 4 ud. (800 g)
# Paquete 3 ud. (645 g)
# Caja 2 paquetes (400 g)
# Caja 4 paquetes (800 g)
# Paquete 205 g
# Caja 2 paquetes (600 g)
# Paquete 4 ud. (800 g)
# Caja 2 paquetes (500 g)
# Paquete 2 ud. (800 g)
# Paquete 425 g
# Paquete 400 g
# Paquete 285 g
# Paquete 200 g
# Paquete 400 g
# Paquete 4 ud. (800 g)
# Caja 8 paquetes (384 g)
# Paquete 225 g
# Paquete 500 g
# Caja 4 paquetes (160 g)
# Caja 500 g
# Paquete 300 g
# Caja 4 paquetes (300 g)
# Caja 8 paquetes (329 g)
# Caja 10 paquetes (440 g)
# Caja 4 paquetes (150 g)
# Caja 5 barritas (140 g)
# Caja 4 paquetes (160 g)
# Caja 8 paquetes (268 g)
# Caja 6 paquetes (252 g)
# Paquete 250 g
# Paquete 210 g
# Paquete 210 g
# Caja 6 paquetes (235,8 g)
# Paquete 280 g
# Paquete 210 g
# Paquete 200 g
# Caja 4 paquetes (150 g)
# Paquete 265 g
# Paquete 150 g
# Paquete 250 g
# Caja 8 paquetes (312 g)
# Bote 150 g
# Caja 300 g
# Caja 520 g
# Caja 6 paquetes (251 g)
# Paquete 145 g
# Paquete 160 g
# Paquete 12 ud. (186 g)
# Caja 125 g
# Paquete 500 g
# Caja 340 g
# Caja 6 paquetes (180 g)
# Caja 1 bandeja (500 g)
# Paquete 24 ud. (255 g)
# Paquete 24 ud. (52 g)
# Bote 175 g
# Paquete 4 packs (120 g)
# Paquete 4 packs (130 g)
# Paquete 4 packs (120 g)
# Paquete 4 packs (130 g)
# Paquete 4 packs (109 g)
# Paquete 4 packs (115,2 g)
# Paquete 200 g
# 2 paquetes x 200 g
# Paquete 225 g
# 2 paquetes x 200 g
# Paquete 200 g
# 4 paquetes x 37,5 g
# Paquete 200 g
# 4 paquetes x 25 g
# 4 paquetes x 31,25 g
# Paquete 140 g
# Paquete 225 g
# 2 paquetes x 100 g
# Paquete 140 g
# Paquete 50 g
# Paquete 200 g
# Paquete 150 g
# Paquete 125 g
# Paquete 200 g
# Pieza 500 g
# Paquete 200 g
# Paquete 200 g
# Paquete 150 g
# Pieza 500 g
# Pieza 235 g
# Pieza 500 g
# Paquete 125 g
# Paquete 150 g
# Paquete 125 g
# Paquete 400 g
# Paquete 150 g
# 2 paquetes x 225 g
# Paquete 200 g
# Paquete 200 g
# Paquete 200 g
# Paquete 250 g
# Paquete 500 g
# Paquete 200 g
# Paquete 225 g
# Paquete 200 g
# Paquete 120 g
# Paquete 300 g
# Paquete 225 g
# Paquete 250 g
# Lata 240 g
# Pieza 2 kg
# Paquete 200 g
# Paquete 400 g
# 2 paquetes x 125 g
# Paquete 150 g
# Paquete 210 g
# Pieza 310 g aprox.
# Paquete 360 g aprox.
# Paquete 200 g
# 4 paquetes x 176 g
# 2 paquetes x 200 g
# 2 paquetes x 170 g
# 2 paquetes x 200 g
# Paquete 170 g
# Paquete 275 g
# 4 paquetes x 160 g
# 2 paquetes x 200 g
# 2 paquetes x 175 g
# 2 paquetes x 200 g
# Paquete 170 g
# 2 paquetes x 175 g
# 2 paquetes x 175 g
# Tarro 460 g (280 g escurrido)
# 2 paquetes x 200 g
# 2 paquetes x 250 g
# 4 paquetes x 140 g
# Paquete 250 g
# Paquete 150 g
# Pieza 500 g
# Paquete 250 g
# Paquete 250 g
# Paquete 150 g
# Pieza 900 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# 1 ud.
# 4 paquetes x 60 g
# Paquete 50 g
# 4 paquetes x 45 g
# 4 paquetes x 31,25 g
# 4 paquetes x 60 g
# Paquete 100 g
# Paquete 90 g aprox.
# Paquete 90 g aprox.
# 4 paquetes x 31,25 g
# Pieza 235 g
# 1 ud.
# 1 ud.
# 1 ud.
# Pieza 500 g aprox.
# Pieza 200 g
# Pieza 820 g aprox.
# Pieza 1,1 kg aprox.
# 4 paquetes x 31,25 g
# 4 paquetes x 37,5 g
# Paquete 50 g
# Paquete 75 g
# 4 paquetes x 56,25 g
# 4 paquetes x 60 g
# 4 paquetes x 37,5 g
# 4 paquetes x 31,25 g
# Pieza 280 g
# 2 paquetes x 100 g
# Bandeja 500 g aprox.
# Bandeja 600 g aprox.
# Bandeja 500 g aprox.
# Bandeja 600 g aprox.
# Bandeja 500 g aprox.
# Bandeja 450 g aprox.
# Bandeja 300 g aprox.
# Bandeja 110 g
# Bandeja 500 g aprox.
# Bandeja 500 g aprox.
# Bandeja 380 g aprox.
# Bandeja 500 g aprox.
# Bandeja 600 g aprox.
# Bandeja 500 g aprox.
# Bandeja 550 g aprox.
# Bandeja 550 g aprox.
# Bandeja 500 g aprox.
# Paquete 500 g
# Paquete 500 g
# Paquete 350 g
# Paquete 400 g
# Paquete 500 g
# Bandeja 370 g aprox.
# Bandeja 280 g
# Bandeja 280 g
# Bandeja 470 g aprox.
# Bandeja 900 g aprox.
# Bandeja 400 g aprox.
# Bandeja 650 g aprox.
# Bandeja 650 g aprox.
# Bandeja 360 g aprox.
# Bandeja 510 g aprox.
# Bandeja 400 g aprox.
# Bandeja 450 g aprox.
# Bandeja 680 g aprox.
# Paquete 370 g
# Bandeja 600 g aprox.
# Bandeja 600 g aprox.
# Bandeja 500 g aprox.
# Bandeja 500 g aprox.
# Bandeja 580 g aprox.
# Bandeja 370 g
# Bandeja 600 g aprox.
# Bandeja 600 g aprox.
# Bandeja 290 g aprox.
# Paquete 220 g aprox.
# Paquete 500 g
# Paquete 500 g
# Bandeja 500 g aprox.
# Bandeja 500 g aprox.
# Bandeja 340 g aprox.
# Bandeja 370 g
# Bandeja 450 g aprox.
# Bandeja 465 g aprox.
# Bandeja 380 g aprox.
# Bandeja 400 g aprox.
# Caja 500 g
# Caja 5 bolsitas (175 g)
# Paquete 500 g
# Caja 400 g
# Caja 500 g
# Caja 500 g
# Caja 500 g
# Caja 420 g
# Caja 500 g
# Caja 375 g
# Paquete 400 g
# Caja 500 g
# Caja 450 g
# Paquete 500 g
# Caja 500 g
# Paquete 400 g
# Caja 625 g
# Paquete 500 g
# Paquete 500 g
# Caja 375 g
# Caja 425 g
# Paquete 500 g
# Paquete 500 g
# Caja 375 g
# Paquete 500 g
# Paquete 400 g
# Caja 500 g
# Paquete 1 kg
# Paquete 500 g
# Paquete 250 g
# Paquete 400 g
# Paquete 375 g
# Caja 400 g
# Paquete 400 g
# Caja 6 barritas (120 g)
# Caja 6 barritas (127 g)
# Caja 6 barritas (138 g)
# Caja 6 barritas (150 g)
# Caja 4 barritas (120 g)
# Caja 3 barritas (120 g)
# Caja 3 barritas (180 g)
# Caja 6 barritas (120 g)
# Caja 6 paquetes (252 g)
# Caja 5 barritas (125 g)
# Caja 3 barritas (90 g)
# Caja 4 barritas (138 g)
# Paquete 4 ud. (800 g)
# Caja 10 paquetes (411 g)
# Caja 3 paquetes (570 g)
# Paquete 3 ud. (600 g)
# Paquete 4 ud. (800 g)
# Paquete 3 ud. (645 g)
# Caja 2 paquetes (400 g)
# Caja 4 paquetes (800 g)
# Paquete 205 g
# Caja 2 paquetes (600 g)
# Paquete 4 ud. (800 g)
# Caja 2 paquetes (500 g)
# Paquete 2 ud. (800 g)
# Paquete 425 g
# Paquete 400 g
# Paquete 285 g
# Paquete 200 g
# Paquete 400 g
# Paquete 4 ud. (800 g)
# Caja 8 paquetes (384 g)
# Paquete 225 g
# Paquete 500 g
# Caja 4 paquetes (160 g)
# Caja 500 g
# Paquete 300 g
# Caja 4 paquetes (300 g)
# Caja 8 paquetes (329 g)
# Caja 10 paquetes (440 g)
# Caja 4 paquetes (150 g)
# Caja 5 barritas (140 g)
# Caja 4 paquetes (160 g)
# Caja 8 paquetes (268 g)
# Caja 6 paquetes (252 g)
# Paquete 250 g
# Paquete 210 g
# Paquete 210 g
# Caja 6 paquetes (235,8 g)
# Paquete 280 g
# Paquete 210 g
# Paquete 200 g
# Caja 4 paquetes (150 g)
# Paquete 265 g
# Paquete 150 g
# Paquete 250 g
# Caja 8 paquetes (312 g)
# Bote 150 g
# Caja 300 g
# Caja 520 g
# Caja 6 paquetes (251 g)
# Paquete 145 g
# Paquete 160 g
# Paquete 12 ud. (186 g)
# Caja 125 g
# Paquete 500 g
# Caja 340 g
# Caja 6 paquetes (180 g)
# Caja 1 bandeja (500 g)
# Paquete 24 ud. (255 g)
# Paquete 24 ud. (52 g)
# Bote 175 g
# Paquete 4 packs (120 g)
# Paquete 4 packs (130 g)
# Paquete 4 packs (120 g)
# Paquete 4 packs (130 g)
# Paquete 4 packs (109 g)
# Paquete 4 packs (115,2 g)
# Paquete 200 g
# 2 paquetes x 200 g
# Paquete 225 g
# 2 paquetes x 200 g
# Paquete 200 g
# 4 paquetes x 37,5 g
# Paquete 200 g
# 4 paquetes x 25 g
# 4 paquetes x 31,25 g
# Paquete 140 g
# Paquete 225 g
# 2 paquetes x 100 g
# Paquete 140 g
# Paquete 50 g
# Paquete 200 g
# Paquete 150 g
# Paquete 125 g
# Paquete 200 g
# Pieza 500 g
# Paquete 200 g
# Paquete 200 g
# Paquete 150 g
# Pieza 500 g
# Pieza 235 g
# Pieza 500 g
# Paquete 125 g
# Paquete 150 g
# Paquete 125 g
# Paquete 400 g
# Paquete 150 g
# 2 paquetes x 225 g
# Paquete 200 g
# Paquete 200 g
# Paquete 200 g
# Paquete 250 g
# Paquete 500 g
# Paquete 200 g
# Paquete 225 g
# Paquete 200 g
# Paquete 120 g
# Paquete 300 g
# Paquete 225 g
# Paquete 250 g
# Lata 240 g
# Pieza 2 kg
# Paquete 200 g
# Paquete 400 g
# 2 paquetes x 125 g
# Paquete 150 g
# Paquete 210 g
# Pieza 310 g aprox.
# Paquete 1 kg
# Paquete 6 bolsitas (1 kg)
# Paquete 350 g
# Paquete 600 g
# Paquete 600 g
# Paquete 600 g
# Bandeja 1,1 kg
# Caja 2 bandejas (600 g)
# Caja 12 ud. (1,1 kg)
# Caja 2 bandejas (600 g)
# Caja 2 bandejas (600 g)
# Caja 2 ud. (600 g)
# Paquete 600 g
# Bol 309 g
# Paquete 1 kg
# Paquete 1 kg
# Paquete 300 g aprox.
# Paquete 350 g aprox.
# Paquete 2 kg
# Paquete 800 g aprox.
# Paquete 600 g aprox.
# Pieza 1,2 kg aprox.
# Paquete 430 g aprox.
# Pieza 530 g aprox.
# Paquete 1 kg aprox.
# Paquete 750 g
# Caja 12 ud. (684 ml)
# Caja 8 ud. (800 ml)
# Caja 6 ud. (720 ml)
# Caja 6 ud. (480 ml)
# Caja 8 ud. (480 ml)
# Caja 6 ud. (870 ml)
# Caja 8 ud. (456 ml)
# Caja 6 ud. (510 ml)
# Caja 8 ud. (480 ml)
# Caja 6 ud. (216 ml)
# Caja 8 ud. (480 ml)
# Caja 4 ud. (326 ml)
# Caja 6 ud. (216 ml)
# Caja 6 ud. (720 ml)
# Caja 2 ud. (350 ml)
# Caja 12 ud. (444 ml)
# Caja 6 ud. (720 ml)
# Caja 6 ud. (720 ml)
# Caja 6 ud. (720 ml)
# 6 ud. x 200 ml
# Caja 10 ud. (750 ml)
# Tarrina 1 L
# Tarrina 1 L
# Bote 500 ml
# Bote 500 ml
# Bote 500 ml
# Tarrina 950 ml
# Bote 500 ml
# Tarrina 1 L
# Tarrina 950 ml
# Bote 500 ml
# Bote 500 ml
# Tarrina 950 ml
# Bote 500 ml
# Bote 500 ml
# Bote 500 ml
# Caja 1 L
# Caja 10 raciones (1 L)
# Paquete 24 ud. (52 g)
# Bote 150 g
# Bote 175 g
# 5 paquetes x 2 kg
# Paquete 2 kg
# Paquete 2 kg
# Paquete 685 g escurrido
# Granel 150 g aprox.
# Caja 2 kg
# Granel 150 g aprox.
# Caja 1 kg aprox.
# Caja 500 g
# Caja 600 g escurrido
# Granel 150 g aprox.
# Caja 1 kg aprox.
# Bandeja 350 g
# Caja 500 g aprox.
# Bandeja 220 g escurrido
# Paquete 360 g escurrido
# Bandeja 220 g escurrido
# Paquete 200 g
# Paquete 360 g escurrido
# Bandeja 250 g
# Caja 500 g
# Pieza 450 g escurrido
# Granel 150 g aprox.
# Caja 500 g
# Pieza 715 g
# Caja 500 g escurrido
# Paquete 32 ud. (600 g)
# Paquete 275 g escurrido
# Caja 450 g
# Paquete 450 g
# Paquete 600 g escurrido
# Pieza 200 g aprox. escurrido
# Paquete 375 g escurrido
# Pieza 100 g aprox. escurrido
# Paquete 485 g escurrido
# Pieza 400 g aprox. escurrido
# Pieza 300 g aprox. escurrido
# Paquete 580 g escurrido
# Paquete 360 g escurrido
# Paquete 475 g escurrido
# Paquete 900 g escurrido
# Caja 400 g
# Bandeja 260 g
# Paquete 600 g escurrido
# Paquete 475 g escurrido
# Pieza 450 g aprox. escurrido
# Paquete 500 g
# Paquete 360 g escurrido
# Paquete 400 g escurrido
# Paquete 1 kg escurrido
# Pieza 500 g aprox. escurrido
# Paquete 400 g escurrido
# Paquete 8 ud. (32 g)
# Paquete 970 g escurrido
# Pieza 200 g aprox. escurrido
# Pieza 700 g aprox. escurrido
# Paquete 360 g escurrido
# Paquete 1 kg aprox.
# Paquete 450 g escurrido
# Paquete 600 g escurrido
# Paquete 2 ud. (250 g)
# Paquete 300 g escurrido
# Paquete 600 g escurrido
# Paquete 500 g escurrido
# Bandeja 250 g aprox.
# Pieza 200 g aprox.
# Paquete 350 g
# Paquete 390 g aprox.
# 2 ud. x 285 g
# 400 g
# 390 g
# 390 g
# 540 g
# 400 g
# 540 g
# 410 g
# 390 g
# 390 g
# Paquete 3 ud. (420 g)
# Paquete 2 ud. (400 g)
# Paquete 500 g
# Paquete 350 g
# Paquete 500 g
# Paquete 4 ud. (350 g)
# Paquete 500 g
# Paquete 300 g
# Paquete 400 g
# Paquete 500 g
# Paquete 500 g
# Paquete 625 g
# Paquete 510 g
# Paquete 400 g
# Caja 500 g
# Paquete 500 g
# Paquete 500 g
# Paquete 450 g
# Paquete 500 g
# Paquete 500 g
# Paquete 350 g
# Paquete 300 g
# Paquete 400 g
# Paquete 400 g
# Caja 6 rollitos (300 g)
# Paquete 350 g
# Paquete 300 g
# Caja 480 g
# 10 raciones (750 g)
# 10 raciones (700 g)
# 12 raciones (1,09 kg)
# 8 raciones (710 g)
# 8 raciones (880 g)
# 6 raciones (520 g)
# 6 raciones (500 g)
# 10 raciones (825 g)
# 9 raciones (805 g)
# 24 raciones (1,65 kg)
# 30 raciones (1,9 kg)
# Bandeja 430 g
# 8 raciones (670 g)
# 10 raciones (880 g)
# 8 raciones (635 g)
# 20 raciones (1,4 kg)
# 20 raciones (1,4 kg)
# Paquete 24 ud. (500 g)
# Paquete 6 ud. (240 g)
# Caja 8 ud. (400 g)
# Paquete 300 g
# Paquete 300 g
# Paquete 300 g
# Paquete 1 kg
# Paquete 450 g
# Paquete 300 g
# Paquete 1 kg
# Paquete 1 kg
# Paquete 450 g
# Paquete 1 kg
# Paquete 300 g
# Paquete 400 g
# Paquete 500 g
# Paquete 1 kg
# Paquete 300 g
# Paquete 300 g
# Paquete 450 g
# Paquete 450 g
# Paquete 450 g
# Paquete 450 g
# Paquete 400 g
# Paquete 400 g
# Paquete 400 g
# Paquete 450 g
# Paquete 1 kg
# Paquete 450 g
# Paquete 450 g
# Paquete 150 g
# Paquete 185 g
# Paquete 400 g
# Paquete 450 g
# Paquete 400 g
# Caja 6 rollitos (300 g)
# Paquete 350 g
# Paquete 1 kg
# Paquete 450 g
# Paquete 1 kg
# Paquete 75 g
# Paquete 500 g
# Paquete 600 g
# Paquete 125 g
# Paquete 450 g
# Paquete 600 g
# Paquete 450 g
# Paquete 10 ud. (230 g)
# 2 paquetes x 125 g
# Paquete 150 g
# Paquete 210 g
# Pieza 310 g aprox.
# Paquete 360 g aprox.
# Paquete 200 g
# 4 paquetes x 176 g
# 2 paquetes x 200 g
# 2 paquetes x 170 g
# 2 paquetes x 200 g
# Paquete 170 g
# Paquete 275 g
# 4 paquetes x 160 g
# 2 paquetes x 200 g
# 2 paquetes x 175 g
# 2 paquetes x 200 g
# Paquete 170 g
# 2 paquetes x 175 g
# 2 paquetes x 175 g
# Tarro 460 g (280 g escurrido)
# 2 paquetes x 200 g
# 2 paquetes x 250 g
# 4 paquetes x 140 g
# Paquete 250 g
# Paquete 150 g
# Pieza 500 g
# Paquete 250 g
# Paquete 250 g
# Paquete 150 g
# Pieza 900 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# Paquete 150 g
# 1 ud.
# 4 paquetes x 60 g
# Paquete 50 g
# 4 paquetes x 45 g
# 4 paquetes x 31,25 g
# 4 paquetes x 60 g
# Paquete 100 g
# Paquete 90 g aprox.
# Paquete 90 g aprox.
# 4 paquetes x 31,25 g
# Pieza 235 g
# 1 ud.
# 1 ud.
# 1 ud.
# Pieza 500 g aprox.
# Pieza 200 g
# Pieza 820 g aprox.
# Pieza 1,1 kg aprox.
# 4 paquetes x 31,25 g
# 4 paquetes x 37,5 g
# Paquete 50 g
# Paquete 75 g
# 4 paquetes x 56,25 g
# 4 paquetes x 60 g
# 4 paquetes x 37,5 g
# 4 paquetes x 31,25 g
# Pieza 280 g
# 2 paquetes x 100 g
# Paquete 65 g
# 4 paquetes x 56,25 g
# Paquete 100 g
# Paquete 90 g aprox.
# Paquete 90 g aprox.
# Pieza 280 g
# Pieza 200 g
# 1 ud.
# Pieza 500 g aprox.
# Pieza 980 g aprox.
# Pieza 1,15 kg aprox.
# Pieza 350 g
# Pieza 350 g
# 4 paquetes x 31,25 g
# 4 paquetes x 31,25 g
# Pieza 330 g aprox.
# Paquete 150 g
# Paquete 150 g
# Paquete 90 g aprox.
# Paquete 90 g aprox.
# Paquete 200 g
# Pieza 400 g aprox.
# Pieza 500 g aprox.
# Pieza 1,9 kg aprox.
# Pieza 1,09 kg aprox.
# 4 paquetes x 25 g
# Paquete 120 g
# 2 paquetes x 90 g
# Paquete 240 g
# Paquete 160 g aprox.
# Paquete 160 g aprox.
# Paquete 160 g aprox.
# Paquete 90 g aprox.
# Paquete 90 g aprox.
# Paquete 90 g aprox.
# Paquete 90 g aprox.
# 2 paquetes x 120 g
# 2 ud. x 120 g
# Paquete 120 g
# 2 paquetes x 100 g
# Pieza 220 g
# 290 g aprox.
# Paquete 200 g
# Paquete 360 g aprox.
# Paquete 100 g
# Pieza 900 g aprox.
# Paquete 100 g
# Paquete 120 g
# Paquete 90 g
# Pieza 7,6 kg aprox.
# Pieza 5 kg aprox.
# Pieza 4,61 kg aprox.
# Pieza 8,5 kg aprox.
# Pieza 9 kg aprox.
# Pieza 9 kg aprox.
# 3 latas x 87 g
# 3 latas x 80 g
# Tarro 160 g
# Tarro 160 g
# Bandeja 100 g
# 3 latas x 80 g
# Tarro 160 g
# Bandeja 100 g
# Tarrina 160 g
# Tarro 160 g
# 2 latas x 80 g
# Tarro 120 g
# Tarro 160 g
# 3 latas x 80 g
# 3 latas x 80 g
# Paquete 100 g
# Bandeja 100 g
# Lata 130 g
# Paquete 100 g
# Paquete 100 g
# Tarro 120 g
# 2 latas x 80 g
# 2 latas x 80 g
# Tarro 160 g
# Tarrina 250 g
# Tarrina 250 g
# Pieza 1 ud.
# Tarrina 200 g
# Pieza 1,63 kg aprox.
# Pieza 330 g aprox.
# Pieza 410 g aprox.
# Pieza 1,03 kg aprox.
# Pieza 230 g aprox.
# ...
# Lata 111 g (63 g escurrido)
# Lata 90 g (55 g escurrido)
# Lata 110 g (63 g escurrido)
# Lata 111 g (63 g escurrido)
# Lata 185 g (90 g escurrido)
# 2 latas x 106 g
# Lata 111 g (69 g escurrido)
# Lata 111 g (69 g escurrido)
# Lata 111 g (69 g escurrido)
# Lata 111 g (69 g escurrido)
# Lata 111 g (69 g escurrido)
# 3 latas x 140 g
# 3 latas x 70 g
# Tarro 200 g (110 g escurrido)
# Tarro 345 g (205 g escurrido)
# Tarro 540 g (325 g escurrido)
# Bote 355 g (180 g escurrido)
# 3 latas x 85 g
# Bote 355 g (180 g escurrido)
# Tarro 340 g (275 g escurrido)
# Bote 390 g (250 g escurrido)
# 3 latas x 120 g
# 3 latas x 60 g
# Tarro 660 g (360 g escurrido)
# Bandeja 290 g
# Bote 390 g (240 g escurrido)
# Tarro 290 g (175 g escurrido)
# Tarro 535 g (330 g escurrido)
# Bandeja 260 g
# Tarro 425 g (250 g escurrido)
# Tarro 660 g (360 g escurrido)
# Tarro 425 g (250 g escurrido)
# Tarro 535 g (320 g escurrido)
# Bandeja 290 g
# Tarro 660 g (400 g escurrido)
# Tarro 410 g (250 g escurrido)
# Tarro 280 g (155 g escurrido)
# Tarro 425 g (250 g escurrido)
# Tarro 225 g (150 g escurrido)
# 2 latas x 180 g
# Tarro 230 g (125 g escurrido)
# Tarro 190 g
# 2 latas x 100 g
# Bote 160 g
# Tarro 660 g
# Tarro 290 g (235 g escurrido)
# Caja 30 cápsulas (17,85 g)
# Caja 30 cápsulas (18 g)
# Caja 30 cápsulas (15,45 g)
# Caja 15 sticks (75 g)
# Caja 60 cápsulas (32,7 g)
# Caja 30 cápsulas (15,02 g)
# Caja 30 cápsulas (19,4 g)
# Tubo 20 ud. (78 g)
# Caja 30 comprimidos (26,55 g)
# Caja 3 barritas (180 g)
# Bote 36 ud. (108 g)
# Caja 30 cápsulas (17 g)
# Caja 30 cápsulas (17,85 g)
# Bote 30 ml
# Pieza 160 g aprox.
# Pieza 170 g aprox.
# Pieza 300 g aprox.
# Bandeja 500 g aprox.
# Bandeja 500 g aprox.
# Pieza 240 g aprox.
# Bolsa 1,5 kg aprox.
# Pieza 150 g aprox.
# 1,5 kg aprox.
# Pieza 290 g aprox.
# Bolsa 1,5 kg aprox.
# Pieza 100 g aprox.
# Pieza 190 g aprox.
# Pieza 130 g aprox.
# Pieza 240 g aprox.
# Bolsa 1,5 kg aprox.
# 1/4 Pieza 1,75 kg aprox.
# 1/2 Pieza 3,36 kg aprox.
# Pieza 6,96 kg aprox.
# 1/2 Pieza 1,68 kg aprox.
# Pieza 3,24 kg aprox.
# Malla 1 kg
# Pieza 160 g aprox.
# Pieza 130 g aprox.
# 1,5 kg
# Malla 2 kg
# Pieza 280 g aprox.
# Pieza 160 g aprox.
# Pieza 170 g aprox.
# Pieza 300 g aprox.
# Bandeja 500 g aprox.
# Bandeja 500 g aprox.
# Pieza 240 g aprox.
# Bolsa 1,5 kg aprox.
# Pieza 150 g aprox.
# 1,5 kg aprox.
# Pieza 290 g aprox.
# Bolsa 1,5 kg aprox.
# Pieza 100 g aprox.
# Pieza 190 g aprox.
# Pieza 130 g aprox.
# Pieza 240 g aprox.
# Bolsa 1,5 kg aprox.
# 1/4 Pieza 1,75 kg aprox.
# 1/2 Pieza 3,36 kg aprox.
# Pieza 6,96 kg aprox.
# 1/2 Pieza 1,68 kg aprox.
# Pieza 3,24 kg aprox.
# Malla 1 kg
# Pieza 160 g aprox.
# Pieza 130 g aprox.
# 1,5 kg
# Malla 2 kg
# Pieza 280 g aprox.
# Malla 3 kg
# Malla 5 kg
# Pieza 290 g aprox.
# Pieza 80 g aprox.
# Pieza 110 g aprox.
# Bandeja 1 kg aprox.
# Pieza 190 g aprox.
# 550 g aprox.
# Pieza 2,14 kg aprox.
# 1/2 Pieza 1,07 kg aprox.
# Tarrina 500 g
# Tarrina 200 g
# Pieza 450 g aprox.
# Bote 500 g aprox.
# Pieza 480 g aprox.
# Bandeja 500 g aprox.
# Bandeja 1 kg aprox.
# Bandeja 170 g
# Bandeja 125 g
# Vaso 225 g
# Tarrina 500 g
# Pieza 1 ud.
# Paquete 250 g
# Paquete 2 ud.
# Paquete 100 g
# Paquete 125 g
# Paquete 250 g
# Paquete 175 g
# Paquete 3 ud.
# Paquete 1 ud.
# Bandeja 450 g
# Paquete 175 g
# Paquete 300 g
# Paquete 150 g
# Paquete 50 g
# Paquete 6 ud.
# Paquete 200 g
# Paquete 100 g
# Paquete 200 g
# Paquete 1 ud.
# Paquete 150 g
# Paquete 1 ud.
# Paquete 100 g
# Paquete 200 g
# Bol 210 g
# Bol 192 g
# 218  Cacao, café e infusiones  Café cápsula y monodosis
#
#                           descripcion                       unidades  \
# 218  Café en cápsula espresso Tassimo  Paquete 16 cápsulas (118,4 g)
#
#           precio     code       compare
# 218  5,30 € /ud.  11873.0   44,764 €/kg

# %%
df.shape
# Out:
# (7430, 7)

# %% [markdown]
# ## DUPLICADOS

# %%
def dupli_rows(df):
    "How many duplicate rows there is"
    duplicates = df.shape[0] - df.drop_duplicates().shape[0]
    print(f'There is {duplicates} duplicate rows')
    return 

dupli_rows(df)
# Out:
# There is 4547 duplicate rows

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2883, 7)

# %% [markdown]
# ## PRECIO

# %%
def format_price(x):
    
    """
    Decompose and fromate values for the colum price
    
    input: string 
    output: lsit, values of each key already casted:
        info: pos[0]: str 
        valores: pos[1]: float
        descuento: pos[2]: float/np.nan(float) (where there is a discount or not)
    
    """
    
    # 1. Replace the € simbol and splits by the "/" ch -- generates a list of 2 elements (nums - text)
    x = x.replace("€", "").split("/")
    
    # 2. Split by the "/" to extract the info, keep last part(always at the end)
    info = x[-1].replace(".", "") #(str)
    
    # 3. Splits by the "/" to extract the num values:
    num_values = x[0:-1][0].replace("," , ".").strip().split(" ")
    
    # 4. Extracts and formats price value:
    price = float(num_values[0])
    
    # 5. Extracts and formats discount_price if not dicount np.nan
    discount = [np.nan if len(num_values) == 1 else float(num_values[1])][0]
    
    return [info, price, discount]

# %%
# Apply the function and get the element for each colum: 

"He decidodo que esto no aporta nada"
#df["price_info"] = df["precio"].apply(format_price).apply(lambda x:x[0])
df["price_eu"] = df["precio"].apply(format_price).apply(lambda x:x[1])
df["price_disc_eu"] = df["precio"].apply(format_price).apply(lambda x:x[2])

#Drop old column:
df.drop("precio", axis=1, inplace=True)

# %%
df
# Out:
#                        categoria             subcategoria  \
# 0      Aceite, especias y salsas    Aceite, vinagre y sal
# 1      Aceite, especias y salsas    Aceite, vinagre y sal
# 2      Aceite, especias y salsas    Aceite, vinagre y sal
# 3      Aceite, especias y salsas    Aceite, vinagre y sal
# 4      Aceite, especias y salsas    Aceite, vinagre y sal
# ..                           ...                      ...
# 524  Huevos, leche y mantequilla  Mantequilla y margarina
# 525  Huevos, leche y mantequilla  Mantequilla y margarina
# 526  Huevos, leche y mantequilla  Mantequilla y margarina
# 527  Huevos, leche y mantequilla  Mantequilla y margarina
# 528  Huevos, leche y mantequilla  Mantequilla y margarina
#
#                                            descripcion  \
# 0                       Aceite de oliva 0,4º Hacendado
# 1               Aceite de oliva virgen extra Hacendado
# 2               Aceite de oliva virgen extra Hacendado
# 3    Aceite de oliva virgen extra Hacendado Gran Se...
# 4                         Aceite de oliva 1º Hacendado
# ..                                                 ...
# 524                          Leche evaporada Hacendado
# 525                            Crema de soja Hacendado
# 526                             Leche de coco Dee Thai
# 527     Nata ligera para cocinar sin lactosa Hacendado
# 528                               Salsa bechamel Knorr
#
#                    unidades     code      compare  price_eu  price_disc_eu
# 0               Botella 1 L   4240.0     9,25 €/L      9.25            NaN
# 1               Garrafa 3 L   4717.0     9,85 €/L     29.55            NaN
# 2               Botella 1 L   4740.0     9,90 €/L      9.90            NaN
# 3            Botella 750 ml   4706.0    10,80 €/L      8.10            NaN
# 4               Botella 1 L   4640.0     9,25 €/L      9.25            NaN
# ..                      ...      ...          ...       ...            ...
# 524  3 mini bricks x 200 ml  15599.0   2,667 €/kg      1.60            NaN
# 525            Brick 200 ml  10376.0     5,50 €/L      1.10            NaN
# 526             Bote 400 ml  17174.0     3,50 €/L      1.40            NaN
# 527  3 mini bricks x 200 ml  10320.0     4,00 €/L      2.40            NaN
# 528            Brick 500 ml  86713.0     4,50 €/L      2.25            NaN
#
# [2883 rows x 8 columns]

# %% [markdown]
# ## - MARCA

# %% [markdown]
# Hay tres marcas principales que se van a repetir en casi la mitad de articulos, que son los nombres
# de las marcas propias de mercadona:

# %%
"""Funcion que te devuelve la marca si el texto la contiene"""
def marca(x):
    #marcas = ["Hacendado", "Deliplus", "Bosque Verde", "Coca-Cola"]
    
    marcas = ["Hacendado", "Deliplus", "Bosque Verde", "Coca-Cola", "Aquarius", "Compy", "L'Oréal", "Delikuit", 
                "Maybelline", "Gillette", "Nivea", "Puleva", "Incarlopsa", "Tampax", "Gallina Blanca", 
                "El Pozo", "Hero baby", "Finish", "Garnier", "Rimmel London", "Pantene", "Evax", 
                "Dolce Gusto", "Entrepinares", "Mahou"]
    
    
    return [i for i in marcas if i in x]

# %%
#Aplicamos la funcion, como realmente devuelve una lista, si esta vacia (no match) --> np.nan
df["marca"] = df["descripcion"].apply(marca).apply(lambda x: x[0] if x != [] else np.nan)

# %%
#Quiero ver cuantas filas no hemos identificado la marca 
df['marca'].isna().sum()
# Out:
# 1161

# %%
df.sample()
# Out:
#                      categoria  subcategoria                   descripcion  \
# 127  Aceite, especias y salsas  Otras salsas  Salsa fresca Queso Hacendado
#
#           unidades     code      compare  price_eu  price_disc_eu      marca
# 127  Paquete 180 g  17409.0   8,056 €/kg      1.45            NaN  Hacendado

# %% [markdown]
# ### UNIDADES:

# %%
# Por el tema de acentos
df["unidades"] = df["unidades"].apply(unidecode)

#con esto eliminos los puntos de ud. y de aprox.
df["unidades"] = df["unidades"].str.replace(".", "")

# me quito todods los aprox
df["unidades"] = df["unidades"].str.replace("aprox", "")

df["unidades"] = df["unidades"].str.replace("(", "")

df["unidades"] = df["unidades"].str.replace(")", "")

# %%
def format_units(i):
    
    # Format Ex:         (contains "escurrido")
    pattern_1 = r'^(\S+)\s+(\d+(?:,\d+)?\s*[kKgGmlML]+)\s+(\d+\s*[kKgGmlML]+)\s*escurrido$'

    # Fromat Ex:
    pattern_2 = r'^([A-Z][a-zA-Z]+)\s((?:\d+,)?\d+\s(?:[Kk]g|g|L|ml))'

    #Formaat Ex: '8 latas x 330 ml
    pattern_3 = r'(\d+)\s([a-zA-Z\s]+)\sx\s((?:\d+,)?\d+\s(?:kg|ml|g|L))'
    
    #Format Ex:
    pattern_4 = r'(?:\d+,)?\d+\s+(?:kg|g|ml|L)'
    
    
    if re.match(pattern_1, i):

        matches = re.findall(pattern_1, i)

        formato = matches[0][0]  #.capitalize() ya veremos 

        cantidad = f'1 x {matches[0][2]}'

        #Funciona bien -- para comprobar:
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]


    # Formato 1: Paquete 500 g / Tarro 570 g (400 g escurrido)
    if re.match(pattern_2, i):

        matches = re.findall(pattern_2, i)

        formato = matches[0][0]  #.capitalize() ya veremos 

        cantidad = f'1 x {matches[0][1]}'

        #Funciona bien -- para comprobar:
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]


    #Formato 2: '8 latas x 330 ml
    if re.match(pattern_3, i):

        matches = re.findall(pattern_3, i)

        cantidad = f'{matches[0][0]} x {matches[0][2]}'
        formato = matches[0][1]  #.capitalize() ya veremos 

        #Funciona bien -- para comprobar:
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]

    if re.search(pattern_4, i):

        matches = re.findall(pattern_4, i)

        cantidad = f'1 x {matches[0]}'

        formato = i.replace(matches[0], "")

        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]

    else:
        formato = i
        cantidad = np.nan
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]

# %%
df["format"] = df["unidades"].apply(format_units).apply(lambda x:x[0])
df["quantity"] = df["unidades"].apply(format_units).apply(lambda x:x[1])

# %%
# POR AHORA LO VOY A DEJAR COMO ESTA -- LAS UNIDADES DIGO:

#Drop old column:
#df.drop("unidades", axis=1, inplace=True)

# %%
df.rename(columns={"categoria":"category", 
                   "subcategoria":"subcategory", 
                   "descripcion":"description",
                    "unidades":"units",
                    "code": "product_code",
                      "marca" : "brand"}, inplace = True)

# %%
categories = df[["product_code","category", "subcategory"]]

# %%
export_to_csv(df, "codes-categories")
# Out:
# DataFrame successfully exported to codes-categories.csv

# %%
pirce_2024 = df[["product_code","price_eu"]]
pirce_2024["collected_timestamp"] = "13-03-2024"
pirce_2024['collected_timestamp'] = pd.to_datetime(pirce_2024['collected_timestamp'])
# Out:
# /var/folders/k4/q8g97p495cx7f63kbs0wzyc00000gn/T/ipykernel_33447/2561182815.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pirce_2024["collected_timestamp"] = "13-03-2024"
# /var/folders/k4/q8g97p495cx7f63kbs0wzyc00000gn/T/ipykernel_33447/2561182815.py:3: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pirce_2024['collected_timestamp'] = pd.to_datetime(pirce_2024['collected_timestamp'])
# /var/folders/k4/q8g97p495cx7f63kbs0wzyc00000gn/T/ipykernel_33447/2561182815.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pirce_2024['collected_timestamp'] = pd.to_datetime(pirce_2024['collected_timestamp'])

# %%
pirce_2024
# Out:
#      product_code  price_eu collected_timestamp
# 0          4240.0      9.25          2024-03-13
# 1          4717.0     29.55          2024-03-13
# 2          4740.0      9.90          2024-03-13
# 3          4706.0      8.10          2024-03-13
# 4          4640.0      9.25          2024-03-13
# ..            ...       ...                 ...
# 524       15599.0      1.60          2024-03-13
# 525       10376.0      1.10          2024-03-13
# 526       17174.0      1.40          2024-03-13
# 527       10320.0      2.40          2024-03-13
# 528       86713.0      2.25          2024-03-13
#
# [2883 rows x 3 columns]

# %%
export_to_csv(df, "codigos-precios-2024")
# Out:
# DataFrame successfully exported to codigos-precios-2023.csv
