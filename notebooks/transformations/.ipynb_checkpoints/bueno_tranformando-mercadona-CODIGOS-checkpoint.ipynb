# %%
import pandas as pd
import numpy as np
import csv
import re

from unidecode import unidecode #para los acentos

#Deberia revisar lo de Counter que lo uso bastante y no conoxco muy bien la libreria
from collections import Counter

# %%
def export_to_csv(data_frame, file_name):
    """
    Export a DataFrame to a CSV file.

    Parameters:
        - data_frame: pandas DataFrame
        - file_name: str, name of the CSV file (without the extension)
    """
    #print date stamp - datetime.datetime.now()
    
    #t_stamp = str(datetime.datetime.now()).split(".")[0].replace(" ","_")
    
    file_path = f"{file_name}.csv"
    
    data_frame.to_csv(file_path, index=False)
    print(f"DataFrame successfully exported to {file_path}")

# %%
df = pd.read_csv("../../data/srape-mercadona_2024-03-08.csv")

# %%
df.sample()
# Out:
#             categoria subcategoria                              descripcion  \
# 196  Agua y refrescos         Agua  Agua mineral con gas grande San Narciso
#
#         unidades       precio
# 196  Botella 1 L  1,29 € /ud.

# %%
def dupli_rows(df):
    "How many duplicate rows there is"
    duplicates = df.shape[0] - df.drop_duplicates().shape[0]
    print(f'There is {duplicates} duplicate rows')
    return 

dupli_rows(df)
# Out:
# There is 19 duplicate rows

# %%
df.shape
# Out:
# (5035, 5)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (5016, 5)

# %% [markdown]
# ## DUPLICADOS

# %% [markdown]
# # Intoducir los codigos de producto:

# %%
#Extraemos la tabla con los productos y los codigos
df_codes = pd.read_csv("../../data/productos-codigos.csv")

# %%
#Cambiamos el nombre de la columna para que cuadren las columnas 
df_codes.rename(columns={"product":"descripcion"}, inplace=True)

# %%
# Habra algunos codigos que nos pueden dar problemas por el tema de descripciones duplicadas
#Creamos un subset para analizar 
duplicates = df_codes[df_codes.duplicated(subset='descripcion')]

# %%
# Lo que los va a diferencias son las uniodades, por eso lo concatenamos para generar un nombre que sea representativo
duplicates['product_complete'] = duplicates['descripcion'].str.cat(duplicates['unidades'], sep=' ')
# Out:
# /var/folders/k4/q8g97p495cx7f63kbs0wzyc00000gn/T/ipykernel_15228/52811897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   duplicates['product_complete'] = duplicates['descripcion'].str.cat(duplicates['unidades'], sep=' ')

# %%
#Nos quedamos con las columnas deseadas_ 
duplicates = duplicates[["product_complete", "product_code"]]

# %%
duplicates.head(50)
# Out:
#                                       product_complete  product_code
# 1           Aceite de oliva 0,4º Hacendado Botella 1 L        4240.0
# 3    Aceite de oliva virgen extra Hacendado Botella...        4740.0
# 6             Aceite de oliva 1º Hacendado Botella 1 L        4640.0
# 8         Aceite de oliva virgen Hacendado Botella 1 L        4749.0
# 9    Aceite de oliva virgen extra Hacendado Spray 2...        4718.0
# 12   Aceite de girasol refinado 0,2º Hacendado Bote...        4046.0
# 31             Bicarbonato sódico Hacendado Bote 300 g       29006.0
# 51                  Pimentón dulce Hacendado Bote 75 g       34186.0
# 75                     Sal de ajo Hacendado Bote 130 g       34130.0
# 94                     Mayonesa Hacendado Tarro 225 ml       13408.0
# 95                      Mayonesa Hacendado Bote 460 ml       13407.0
# 97                    Mayonesa Hellmann's Tarro 225 ml       17052.0
# 99                  Salsa ligera Ligeresa Tarro 225 ml       17010.0
# 100                  Salsa ligera Ligeresa Bote 430 ml       17039.0
# 105  Salsa ligera Hacendado 60% menos de materia gr...       15794.0
# 119      Tomate frito Hacendado 3 mini bricks x 210 g        17151.0
# 120                 Tomate frito Hacendado Tarro 560 g       17108.0
# 122  Tomate frito receta artesana Hacendado con ace...       17131.0
# 147  Guacamole Hacendado 95% aguacate fresco Tarrin...        3852.0
# 168  Agua mineral grande Font Agudes mineralización...       27335.0
# 169  Agua mineral grande Font Agudes mineralización...       26992.0
# 170  Agua mineral grande Font Agudes mineralización...       26993.0
# 172  Agua mineral mediana Font Agudes mineralizació...       28573.0
# 174  Agua mineral pequeña Font Agudes mineralizació...       27514.0
# 176  Agua mineral pequeña Font Agudes tapón infanti...       27575.0
# 178  Agua mineral grande Bronchales mineralización ...       23448.0
# 179  Agua mineral grande Bronchales mineralización ...       23449.0
# 181  Agua mineral mediana Bronchales mineralización...       28499.0
# 183  Agua mineral pequeña Bronchales mineralización...       27054.0
# 185  Agua mineral pequeña Bronchales tapón infantil...       28567.0
# 187  Agua mineral grande Bezoya mineralización muy ...       27230.0
# 189  Agua mineral grande Ribes mineralización débil...       27155.0
# 190  Agua mineral grande Ribes mineralización débil...       27038.0
# 192  Agua mineral grande Nestlé Aquarel mineralizac...       27232.0
# 194       Agua mineral grande Font Vella Botella 1,5 L       27204.0
# 196  Agua mineral grande Solán de Cabras mineraliza...       27356.0
# 198         Agua mineral grande Viladrau Botella 1,5 L       27221.0
# 203   Agua mineral con gas grande Cortes Botella 1,5 L       27367.0
# 205  Agua mineral con gas pequeña Cortes Botella 50...       27369.0
# 208  Agua mineral con gas grande San Pellegrino Bot...       27893.0
# 211     Agua mineral con gas grande Fonter Botella 1 L       27597.0
# 214           Gaseosa Hacendado pequeña Botella 500 ml       27971.0
# 216             Gaseosa La Casera grande Botella 1,5 L       27735.0
# 218  Bebida isotónica limón Aquarius 8 latas x 330 ml        29605.0
# 219        Bebida isotónica limón Aquarius Lata 330 ml       29625.0
# 221  Bebida isotónica sabor cítrico Iso drink Hacen...       28575.0
# 222  Bebida isotónica sabor cítrico Iso drink Hacen...       28574.0
# 224  Bebida isotónica naranja Aquarius 8 latas x 33...       29604.0
# 225      Bebida isotónica naranja Aquarius Lata 330 ml       29624.0
# 228  Bebida isotónica de naranja Iso drink Hacendad...       28690.0

# %%
# En nuestro df principal, vamos a generar esta misma columna 
df['product_complete'] = df['descripcion'].str.cat(df['unidades'], sep=' ')

# %%
#hacemos un "buscar V" en el df principal, con los productos que pueden dar lugar a confusion. 
df = pd.merge(df, duplicates, on='product_complete', how='left')

# %%
#una vez extraido el codigo, podemos eliminar la columnas
df.drop(columns = "product_complete", inplace=True)

# %%
subset_1 = df[df["product_code"].isna() == True] #Aun no tienen el código
subset_2 = df[df["product_code"].isna() == False] #Ya tienen el código

# %%
subset_1
# Out:
#                       categoria            subcategoria  \
# 0              Agua y refrescos  Isotónico y energético
# 2     Aceite, especias y salsas   Aceite, vinagre y sal
# 10          3,30 € /ud.        4718.0
# ...                 ...           ...
# 4810        1,30 € /ud.       39966.0
# 4813        1,80 € /ud.       80784.0
# 4881        1,50 € /ud.       68331.0
# 5024        2,99 € /ud.        3363.0
# 5025  4,99 €4,79 € /ud.        3362.0
#
# [505 rows x 6 columns]

# %% [markdown]
# # TRANFORMACIONES

# %% [markdown]
# ## PRECIO

# %%
def format_price(x):
    
    """
    Decompose and fromate values for the colum price
    
    input: string 
    output: lsit, values of each key already casted:
        info: pos[0]: str 
        valores: pos[1]: float
        descuento: pos[2]: float/np.nan(float) (where there is a discount or not)
    
    """
    
    # 1. Replace the € simbol and splits by the "/" ch -- generates a list of 2 elements (nums - text)
    x = x.replace("€", "").split("/")
    
    # 2. Split by the "/" to extract the info, keep last part(always at the end)
    info = x[-1].replace(".", "") #(str)
    
    # 3. Splits by the "/" to extract the num values:
    num_values = x[0:-1][0].replace("," , ".").strip().split(" ")
    
    # 4. Extracts and formats price value:
    price = float(num_values[0])
    
    # 5. Extracts and formats discount_price if not dicount np.nan
    discount = [np.nan if len(num_values) == 1 else float(num_values[1])][0]
    
    return [info, price, discount]

# %%
# Apply the function and get the element for each colum: 

"He decidodo que esto no aporta nada"
#df["price_info"] = df["precio"].apply(format_price).apply(lambda x:x[0])
df["price_eu"] = df["precio"].apply(format_price).apply(lambda x:x[1])
df["price_disc_eu"] = df["precio"].apply(format_price).apply(lambda x:x[2])

#Drop old column:
df.drop("precio", axis=1, inplace=True)

# %%
df
# Out:
#                       categoria            subcategoria  \
# 0              Agua y refrescos  Isotónico y energético
# 2     Aceite, especias y salsas   Aceite, vinagre y sal
# 3     Aceite, especias y salsas   Aceite, vinagre y sal
# 4     Aceite, especias y salsas   Aceite, vinagre y sal
# 5     Aceite, especias y salsas   Aceite, vinagre y sal
# ...                         ...                     ...
# 5030                      Zumos  Tomate y otros sabores
# 5031                      Zumos  Tomate y otros sabores
# 5032                      Zumos  Tomate y otros sabores
# 5033                      Zumos  Tomate y otros sabores
# 5034                      Zumos  Tomate y otros sabores
#
#                                             descripcion          unidades  \
# 0                       Bebida isotónica limón Aquarius  8 latas x 330 ml
# 2                        Aceite de oliva 0,4º Hacendado       Botella 1 L
# 3                Aceite de oliva virgen extra Hacendado       Garrafa 3 L
# 4                Aceite de oliva virgen extra Hacendado       Botella 1 L
# 5     Aceite de oliva virgen extra Hacendado Gran Se...    Botella 750 ml
# ...                                                 ...               ...
# 5030  Néctar de maracuyá Hacendado fruta de la pasió...         Brick 1 L
# 5031    Bebida de mango Hacendado sin azúcares añadidos         Brick 1 L
# 5032   Bebida de pomelo Hacendado sin azúcares añadidos         Brick 1 L
# 5033                Zumo de manzana selección Hacendado         Brick 1 L
# 5034                        Néctar de guayaba Hacendado         Brick 1 L
#
#       price_eu  price_disc_eu
# 0         6.80           6.24
# 2         9.25            NaN
# 3        29.55            NaN
# 4         9.90            NaN
# 5         8.10            NaN
# ...        ...            ...
# 5030      0.81            NaN
# 5031      1.25            NaN
# 5032      1.25            NaN
# 5033      1.50            NaN
# 5034      1.30            NaN
#
# [5016 rows x 6 columns]

# %% [markdown]
# ## - MARCA

# %% [markdown]
# Hay tres marcas principales que se van a repetir en casi la mitad de articulos, que son los nombres
# de las marcas propias de mercadona:

# %%
"""Funcion que te devuelve la marca si el texto la contiene"""
def marca(x):
    #marcas = ["Hacendado", "Deliplus", "Bosque Verde", "Coca-Cola"]
    
    marcas = ["Hacendado", "Deliplus", "Bosque Verde", "Coca-Cola", "Aquarius", "Compy", "L'Oréal", "Delikuit", 
                "Maybelline", "Gillette", "Nivea", "Puleva", "Incarlopsa", "Tampax", "Gallina Blanca", 
                "El Pozo", "Hero baby", "Finish", "Garnier", "Rimmel London", "Pantene", "Evax", 
                "Dolce Gusto", "Entrepinares", "Mahou"]
    
    
    return [i for i in marcas if i in x]

# %%
#Aplicamos la funcion, como realmente devuelve una lista, si esta vacia (no match) --> np.nan
df["marca"] = df["descripcion"].apply(marca).apply(lambda x: x[0] if x != [] else np.nan)

# %%
#Quiero ver cuantas filas no hemos identificado la marca 
df['marca'].isna().sum()
# Out:
# 1729

# %%
df.sample()
# Out:
#              categoria                        subcategoria  \
# 3793  Limpieza y hogar  Menaje y conservación de alimentos
#
#                                     descripcion      unidades  price_eu  \
# 3793  Molde de Aluminio Cuadrado 2,7L Alibérico  Paquete 2 ud       2.3
#
#       price_disc_eu marca        format quantity
# 3793            NaN   NaN  Paquete 2 ud      NaN

# %% [markdown]
# ### UNIDADES:

# %%
# Por el tema de acentos
df["unidades"] = df["unidades"].apply(unidecode)

#con esto eliminos los puntos de ud. y de aprox.
df["unidades"] = df["unidades"].str.replace(".", "")

# me quito todods los aprox
df["unidades"] = df["unidades"].str.replace("aprox", "")

df["unidades"] = df["unidades"].str.replace("(", "")

df["unidades"] = df["unidades"].str.replace(")", "")

# %%
def format_units(i):
    
    # Format Ex:         (contains "escurrido")
    pattern_1 = r'^(\S+)\s+(\d+(?:,\d+)?\s*[kKgGmlML]+)\s+(\d+\s*[kKgGmlML]+)\s*escurrido$'

    # Fromat Ex:
    pattern_2 = r'^([A-Z][a-zA-Z]+)\s((?:\d+,)?\d+\s(?:[Kk]g|g|L|ml))'

    #Formaat Ex: '8 latas x 330 ml
    pattern_3 = r'(\d+)\s([a-zA-Z\s]+)\sx\s((?:\d+,)?\d+\s(?:kg|ml|g|L))'
    
    #Format Ex:
    pattern_4 = r'(?:\d+,)?\d+\s+(?:kg|g|ml|L)'
    
    
    if re.match(pattern_1, i):

        matches = re.findall(pattern_1, i)

        formato = matches[0][0]  #.capitalize() ya veremos 

        cantidad = f'1 x {matches[0][2]}'

        #Funciona bien -- para comprobar:
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]


    # Formato 1: Paquete 500 g / Tarro 570 g (400 g escurrido)
    if re.match(pattern_2, i):

        matches = re.findall(pattern_2, i)

        formato = matches[0][0]  #.capitalize() ya veremos 

        cantidad = f'1 x {matches[0][1]}'

        #Funciona bien -- para comprobar:
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]


    #Formato 2: '8 latas x 330 ml
    if re.match(pattern_3, i):

        matches = re.findall(pattern_3, i)

        cantidad = f'{matches[0][0]} x {matches[0][2]}'
        formato = matches[0][1]  #.capitalize() ya veremos 

        #Funciona bien -- para comprobar:
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]

    if re.search(pattern_4, i):

        matches = re.findall(pattern_4, i)

        cantidad = f'1 x {matches[0]}'

        formato = i.replace(matches[0], "")

        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]

    else:
        formato = i
        cantidad = np.nan
        #print(f'{i} ---- {formato} / {cantidad}')

        return [formato, cantidad]

# %%
df["format"] = df["unidades"].apply(format_units).apply(lambda x:x[0])
df["quantity"] = df["unidades"].apply(format_units).apply(lambda x:x[1])

# %%
#Drop old column:
df.drop("unidades", axis=1, inplace=True)

# %%
# Por ultimo añadimos la fecha:
df["date"] = "08-03-2024"
df['date'] = pd.to_datetime(df['date'])

# %%
df.head(50)
# Out:
#                     categoria            subcategoria  \
# 0            Agua y refrescos  Isotónico y energético
# 1            Agua y refrescos  Isotónico y energético
# 2   Aceite, especias y salsas   Aceite, vinagre y sal
# 3   Aceite, especias y salsas   Aceite, vinagre y sal
# 4   Aceite, especias y salsas   Aceite, vinagre y sal
# 5   Aceite, especias y salsas   Aceite, vinagre y sal
# 6   Aceite, especias y salsas   Aceite, vinagre y sal
# 7   Aceite, especias y salsas   Aceite, vinagre y sal
# 8   Aceite, especias y salsas   Aceite, vinagre y sal
# 9   Aceite, especias y salsas   Aceite, vinagre y sal
# 10  Aceite, especias y salsas   Aceite, vinagre y sal
# 11  Aceite, especias y salsas   Aceite, vinagre y sal
# 12  Aceite, especias y salsas   Aceite, vinagre y sal
# 13  Aceite, especias y salsas   Aceite, vinagre y sal
# 14  Aceite, especias y salsas   Aceite, vinagre y sal
# 15  Aceite, especias y salsas   Aceite, vinagre y sal
# 16  Aceite, especias y salsas   Aceite, vinagre y sal
# 17  Aceite, especias y salsas   Aceite, vinagre y sal
# 18  Aceite, especias y salsas   Aceite, vinagre y sal
# 19  Aceite, especias y salsas   Aceite, vinagre y sal
# 20  Aceite, especias y salsas   Aceite, vinagre y sal
# 21  Aceite, especias y salsas   Aceite, vinagre y sal
# 22  Aceite, especias y salsas   Aceite, vinagre y sal
# 23  Aceite, especias y salsas   Aceite, vinagre y sal
# 24  Aceite, especias y salsas   Aceite, vinagre y sal
# 25  Aceite, especias y salsas   Aceite, vinagre y sal
# 26  Aceite, especias y salsas   Aceite, vinagre y sal
# 27  Aceite, especias y salsas   Aceite, vinagre y sal
# 28  Aceite, especias y salsas   Aceite, vinagre y sal
# 29  Aceite, especias y salsas   Aceite, vinagre y sal
# 30  Aceite, especias y salsas   Aceite, vinagre y sal
# 31  Aceite, especias y salsas   Aceite, vinagre y sal
# 32  Aceite, especias y salsas   Aceite, vinagre y sal
# 33  Aceite, especias y salsas   Aceite, vinagre y sal
