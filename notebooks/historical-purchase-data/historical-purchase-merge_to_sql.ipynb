# %%
import os

import pandas as pd
import numpy as np

from unidecode import unidecode

# %%
def export_to_csv(data_frame, file_name):
    """
    Export a DataFrame to a CSV file.

    Parameters:
        - data_frame: pandas DataFrame
        - file_name: str, name of the CSV file (without the extension)
    """
    #print date stamp - datetime.datetime.now()
    
    #t_stamp = str(datetime.datetime.now()).split(".")[0].replace(" ","_")
    
    file_path = f"{file_name}.csv"
    
    data_frame.to_csv(file_path, index=False)
    print(f"DataFrame successfully exported to {file_path}")

# %% [markdown]
# ### Importamos los DF

# %% [markdown]
# ## Scrape 2023

# %%
ref = pd.read_csv("../../data/productos-codigos.csv")
ref
# Out:
#                                                 product        unidades  \
# 0                        Aceite de oliva 0,4º Hacendado     Garrafa 5 L
# 1                        Aceite de oliva 0,4º Hacendado     Botella 1 L
# 2                Aceite de oliva virgen extra Hacendado     Garrafa 3 L
# 3                Aceite de oliva virgen extra Hacendado     Botella 1 L
# 4     Aceite de oliva virgen extra Hacendado Gran Se...  Botella 750 ml
# ...                                                 ...             ...
# 5224   Bebida de pomelo Hacendado sin azúcares añadidos
# 5225     Bebida guayaba Hacendado sin azúcares añadidos
# 5226     Bebida de pera Hacendado sin azúcares añadidos
# 5227                           Zumo de pomelo Hacendado
# 5228                Zumo de manzana selección Hacendado
#
#       product_code
# 0           4241.0
# 1           4240.0
# 2           4717.0
# 3           4740.0
# 4           4706.0
# ...            ...
# 5224       39604.0
# 5225       39659.0
# 5226       39628.0
# 5227       39696.0
# 5228       39922.0
#
# [5229 rows x 3 columns]

# %%
ref.rename(columns={"product":"description"}, inplace=True)

# %%
ref["description"] = ref["description"].str.lower()

# %%
ref['description'] = ref['description'].apply(remove_accents)

# %%
# Create a list of confusing products:

# %%
duplicados = ref[ref.duplicated(subset='description') == True]
duplicados_lista = duplicados["description"].unique()

# %%
not_confusing_ref = ref[ref['description'].isin(duplicados_lista) == False]

# %%
not_confusing_ref = not_confusing_ref[["description", "product_code"]]

# %% [markdown]
# ## Historico 2023

# %%
#this alrready have the codes: 
df_1 = pd.read_csv("../../data/history-pruchase-kike.csv")

# %%
df_1 = df_1[["description", "product_code"]]

# %%
df_1["description"] = df_1["description"].str.lower()
df_1['description'] = df_1['description'].apply(remove_accents)

# %%
not_confusing_df= df_1[df_1['description'].isin(duplicados_lista) == False]

# %%
not_confusing_df.sample()
# Out:
#                               description  product_code
# 638  pan de hamburguesa brioche hacendado          1811

# %%
codes = pd.concat([not_confusing_df, not_confusing_ref])

# %%
codes["description"] = codes["description"].str.strip()

# %% [markdown]
# ### FACTURAS  HISTORICO

# %% [markdown]
# Unimos todos los data Frames a los que hay que incluirles el codigo de prodcuto, y ponemos la descripcion en lower case

# %%
df_2 = pd.read_csv("../../data/history-pruchase-family.csv")

# %%
df_3 = pd.read_csv("../../data/history-pruchase-palacet.csv")

# %%
df_4 = pd.read_csv("../../data/history-pruchase-more.csv")

# %%
df = pd.concat([df_2, df_3, df_4])

# %%
df
# Out:
#                                 description  units  price_eu  unit_price  \
# 0          Jamón serrano Incarlopsa lonchas      1      3.49        3.49
# 1           Queso fresco de cabra Hacendado      1      2.20        2.20
# 2          Queso rallado 4 quesos Hacendado      1      1.59        1.59
# 3     Perlas de mozzarella fresca Hacendado      1      1.70        1.70
# 4    Mozzarella di bufala campana Hacendado      1      1.70        1.70
# ..                                      ...    ...       ...         ...
# 928                 Leche desnatada Pascual      5     32.70        6.54
# 929                           11 Panecillos      1      1.10        1.10
# 930                                 Patatas      1      5.49        5.49
# 931                Queso azul hojas de vaca      1      1.91        1.91
# 932                Salmón ahumado Hacendado      1      2.93        2.93
#
#            date  order_num
# 0    2020-01-10     302316
# 1    2020-01-10     302316
# 2    2020-01-10     302316
# 3    2020-01-10     302316
# 4    2020-01-10     302316
# ..          ...        ...
# 928  2022-07-10   12804912
# 929  2022-07-10   12804912
# 930  2022-07-10   12804912
# 931  2022-07-10   12804912
# 932  2022-07-10   12804912
#
# [1865 rows x 6 columns]

# %%
#INCLUIR TOAS LAS DEMAS FACTURAS ARRIBA Y LUEGO CORRER EL CODIGO - JUNTAR CON LO DE KIKE Y ESTARIA YA TODO

# %%
df["description"] = df["description"].str.lower().str.strip()

# %%
# Function to remove accents using unidecode
def remove_accents(text):
    return unidecode(text)

# Apply the function to the 'Name' column
df['description'] = df['description'].apply(remove_accents)

# %%
df
# Out:
#                                 description  units  price_eu  unit_price  \
# 0          jamon serrano incarlopsa lonchas      1      3.49        3.49
# 1           queso fresco de cabra hacendado      1      2.20        2.20
# 2          queso rallado 4 quesos hacendado      1      1.59        1.59
# 3     perlas de mozzarella fresca hacendado      1      1.70        1.70
# 4    mozzarella di bufala campana hacendado      1      1.70        1.70
# ..                                      ...    ...       ...         ...
# 928                 leche desnatada pascual      5     32.70        6.54
# 929                           11 panecillos      1      1.10        1.10
# 930                                 patatas      1      5.49        5.49
# 931                queso azul hojas de vaca      1      1.91        1.91
# 932                salmon ahumado hacendado      1      2.93        2.93
#
#            date  order_num
# 0    2020-01-10     302316
# 1    2020-01-10     302316
# 2    2020-01-10     302316
# 3    2020-01-10     302316
# 4    2020-01-10     302316
# ..          ...        ...
# 928  2022-07-10   12804912
# 929  2022-07-10   12804912
# 930  2022-07-10   12804912
# 931  2022-07-10   12804912
# 932  2022-07-10   12804912
#
# [1865 rows x 6 columns]

# %%
df = pd.merge(df, codes, how='left', left_on='description', right_on='description')

# %%
df = df.drop_duplicates(subset=['description', 'date'])

# %%
df
# Out:
#                                  description  units  price_eu  unit_price  \
# 0           jamon serrano incarlopsa lonchas      1      3.49        3.49
# 5            queso fresco de cabra hacendado      1      2.20        2.20
# 6           queso rallado 4 quesos hacendado      1      1.59        1.59
# 7      perlas de mozzarella fresca hacendado      1      1.70        1.70
# 8     mozzarella di bufala campana hacendado      1      1.70        1.70
# ...                                      ...    ...       ...         ...
# 2368                 leche desnatada pascual      5     32.70        6.54
# 2369                           11 panecillos      1      1.10        1.10
# 2370                                 patatas      1      5.49        5.49
# 2371                queso azul hojas de vaca      1      1.91        1.91
# 2372                salmon ahumado hacendado      1      2.93        2.93
#
#             date  order_num  product_code
# 0     2020-01-10     302316       59124.0
# 5     2020-01-10     302316       51194.0
# 6     2020-01-10     302316       51237.0
# 7     2020-01-10     302316           NaN
# 8     2020-01-10     302316       51201.0
# ...          ...        ...           ...
# 2368  2022-07-10   12804912           NaN
# 2369  2022-07-10   12804912       83783.0
# 2370  2022-07-10   12804912           NaN
# 2371  2022-07-10   12804912           NaN
# 2372  2022-07-10   12804912           NaN
#
# [1816 rows x 7 columns]

# %%
# Analizar duplicados para ver si podemos incluir los codigos manualmente (ver cuantos hay)
vacios = df[df["product_code"].isna()]

# %%
vacios.head(50)
# Out:
#                                            description  units  price_eu  \
# 7                perlas de mozzarella fresca hacendado      1      1.70
# 9                       refresco coca-cola zero azucar      1      7.56
# 13          dentifrico triple accion colgate con fluor      2      3.50
# 14              aceite de oliva virgen extra hacendado      1      9.50
# 15                    lenteja cocida pardina hacendado      2      0.98
# 17              piadinas pan estilo italiano hacendado      1      1.95
# 18        pan de molde espelta 100% integral hacendado      1      1.10
# 20            gelatina 0% azucar sabor fresa hacendado      1      0.98
# 23               quinoa cocida blanca y roja hacendado      1      1.35
# 24          yogur cremoso hacendado natural edulcorado      1      1.30
# 25              tomate frito receta artesana hacendado      1      1.70
# 26            papel higienico doble rollo bosque verde      2      7.64
# 27             atun claro en aceite de oliva hacendado      2      7.98
# 28   queso untar light blanco pasteurizado philadel...      1      2.10
# 29                           garbanzo cocido hacendado      2      1.40
# 30                                 hogaza 100% natural      1      1.00
# 31                                 agua mineral cortes      2      1.46
# 32                             leche desnatada pascual      2     10.68
# 33                          dentifrico original binaca      2      3.00
# 34                        morcilla oreada d' ontinyent      1      1.34
# 66                                    huevos grandes l      1      1.45
# 67            discos desmaquillantes deliplus redondos      1      0.95
# 69                                    cebolla amarilla      1      1.89
# 70                                          ajo morado      1      1.20
# 72       desodorante roll-on dermo extra control sanex      1      1.80
# 74    esparragos muy gruesos hacendado blancos enteros      1      2.53
# 75   yogur bifidus desnatado hacendado frutas del b...      1      0.95
# 76           compresa con alas normal evax cotton like      1      3.95
# 77           lavavajillas ultra original fairy liquido      1      2.80
# 79                                 agua mineral cortes      1      0.73
# 81   queso untar light blanco pasteurizado philadel...      1      2.10
# 82                          galletas cookies hacendado      1      1.25
# 83                                       tomate cherry      1      1.49
# 84            limpiacristales y multiusos bosque verde      1      1.15
# 86   champu agua de coco fructis raices grasas, pun...      1      2.95
# 87                            arroz redondo la fallera      1      1.35
# 88                                             platano      6      2.20
# 90                          dentifrico original binaca      1      1.50
# 97                                maiz dulce hacendado      1      0.95
# 98              tomate frito receta artesana hacendado      1      1.70
# 99             queso rallado hacendado especial fundir      1      1.00
# 100                                hogaza 100% natural      1      1.00
# 101             cafe en capsula sontuoso l'or espresso      2      6.58
# 102                          chocolate con leche lindt      1      1.15
# 103           papel higienico doble rollo bosque verde      1      3.74
# 104            cafe en capsula ristretto l'or espresso      3      9.87
# 106                           lenteja cocida hacendado      2      1.18
# 107                          garbanzo cocido hacendado      1      0.70
# 108                            leche desnatada pascual      2     10.68
# 109                   pan de molde con avena hacendado      1      1.25
#
#      unit_price        date  order_num  product_code
# 7      1.700000  2020-01-10     302316           NaN
# 9      7.560000  2020-01-10     302316           NaN
# 13     1.750000  2020-01-10     302316           NaN
# 14     9.500000  2020-01-10     302316           NaN
# 15     0.490000  2020-01-10     302316           NaN
# 17     1.950000  2020-01-10     302316           NaN
# 18     1.100000  2020-01-10     302316           NaN
# 20     0.980000  2020-01-10     302316           NaN
# 23     1.350000  2020-01-10     302316           NaN
# 24     1.300000  2020-01-10     302316           NaN
# 25     1.700000  2020-01-10     302316           NaN
# 26     3.820000  2020-01-10     302316           NaN
# 27     3.990000  2020-01-10     302316           NaN
# 28     2.100000  2020-01-10     302316           NaN
# 29     0.700000  2020-01-10     302316           NaN
# 30     1.000000  2020-01-10     302316           NaN
# 31     0.730000  2020-01-10     302316           NaN
# 32     5.340000  2020-01-10     302316           NaN
# 33     1.500000  2020-01-10     302316           NaN
# 34     1.340000  2020-01-10     302316           NaN
# 66     1.450000  2019-02-27     125935           NaN
# 67     0.950000  2019-02-27     125935           NaN
# 69     1.890000  2019-02-27     125935           NaN
# 70     1.200000  2019-02-27     125935           NaN
# 72     1.800000  2019-02-27     125935           NaN
# 74     2.530000  2019-02-27     125935           NaN
# 75     0.950000  2019-02-27     125935           NaN
# 76     3.950000  2019-02-27     125935           NaN
# 77     2.800000  2019-02-27     125935           NaN
# 79     0.730000  2019-02-27     125935           NaN
# 81     2.100000  2019-02-27     125935           NaN
# 82     1.250000  2019-02-27     125935           NaN
# 83     1.490000  2019-02-27     125935           NaN
# 84     1.150000  2019-02-27     125935           NaN
# 86     2.950000  2019-02-27     125935           NaN
# 87     1.350000  2019-02-27     125935           NaN
# 88     0.366667  2019-02-27     125935           NaN
# 90     1.500000  2019-02-27     125935           NaN
# 97     0.950000  2019-02-27     125935           NaN
# 98     1.700000  2019-02-27     125935           NaN
# 99     1.000000  2019-02-27     125935           NaN
# 100    1.000000  2019-02-27     125935           NaN
# 101    3.290000  2019-02-27     125935           NaN
# 102    1.150000  2019-02-27     125935           NaN
# 103    3.740000  2019-02-27     125935           NaN
# 104    3.290000  2019-02-27     125935           NaN
# 106    0.590000  2019-02-27     125935           NaN
# 107    0.700000  2019-02-27     125935           NaN
# 108    5.340000  2019-02-27     125935           NaN
# 109    1.250000  2019-02-27     125935           NaN

# %%
export_to_csv(vacios, "../../data/vacios_02")
# Out:
# DataFrame successfully exported to ../../data/vacios_02.csv

# %%
df = pd.merge(df, codes, on='description', how='left')

# %%
export_to_csv(df, "../../data/history-purchase")
# Out:
# DataFrame successfully exported to ../../data/history-purchase.csv

# %% [markdown]
# ### Set up SQL connection
# First we load the ".env" file so that we can load the user's secret log in info to SQL.

# %%
password = os.getenv("sql_password")
dbName = 'mercadona'
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
engine

# %% [markdown]
# ### Load the data
# Now that our connection is set up, we load the information of the order history retreived from the Mercadona

# %% [markdown]
# #### Upload Order History
# Upload the Order History to the "order_history" table in the "mercadona" schema.
