# %%
import os

import pandas as pd
import numpy as np

# %%
def export_to_csv(data_frame, file_name):
    """
    Export a DataFrame to a CSV file.

    Parameters:
        - data_frame: pandas DataFrame
        - file_name: str, name of the CSV file (without the extension)
    """
    #print date stamp - datetime.datetime.now()
    
    #t_stamp = str(datetime.datetime.now()).split(".")[0].replace(" ","_")
    
    file_path = f"{file_name}.csv"
    
    data_frame.to_csv(file_path, index=False)
    print(f"DataFrame successfully exported to {file_path}")

# %%
pwd
# Out:
# '/Users/Moni/Ironhack/my_ironhack/projects/final-project/notebooks'

# %% [markdown]
# # TABLA HISTORICO DE PEDIDOS

# %%
df_23 = pd.read_csv("../data/Mercadona Scraping 2023-03-11_21-39-33.csv", delimiter="~")

# %%
df_23 = [["product", "product_type", "product_volume", "product_code"]]
# Out:
#                                                 product   product_type  \
# 0                        Aceite de oliva 0,4º Hacendado        Garrafa
# 1                        Aceite de oliva 0,4º Hacendado        Botella
# 2                Aceite de oliva virgen extra Hacendado        Garrafa
# 3                Aceite de oliva virgen extra Hacendado        Botella
# 4     Aceite de oliva virgen extra Hacendado Gran Se...        Botella
# ...                                                 ...            ...
# 5224   Bebida de pomelo Hacendado sin azúcares añadidos  Not available
# 5225     Bebida guayaba Hacendado sin azúcares añadidos  Not available
# 5226     Bebida de pera Hacendado sin azúcares añadidos  Not available
# 5227                           Zumo de pomelo Hacendado  Not available
# 5228                Zumo de manzana selección Hacendado  Not available
#
#      product_volume product_price_per_unit  product_price product_unit  \
# ...

# %%
df = df_23[["product", "product_price"]]

# %%
df
# Out:
#                                                 product  product_price
# 0                        Aceite de oliva 0,4º Hacendado          23.63
# 1                        Aceite de oliva 0,4º Hacendado           4.77
# 2                Aceite de oliva virgen extra Hacendado          16.75
# 3                Aceite de oliva virgen extra Hacendado           5.63
# 4     Aceite de oliva virgen extra Hacendado Gran Se...           5.11
# ...                                                 ...            ...
# 5224   Bebida de pomelo Hacendado sin azúcares añadidos           1.25
# 5225     Bebida guayaba Hacendado sin azúcares añadidos           1.30
# 5226     Bebida de pera Hacendado sin azúcares añadidos           1.10
# 5227                           Zumo de pomelo Hacendado           1.45
# 5228                Zumo de manzana selección Hacendado           1.50
#
# [5229 rows x 2 columns]

# %%
duplis = df[df.duplicated(subset=['product'])]
# Out:
#                                                 product  product_price
# 1                        Aceite de oliva 0,4º Hacendado           4.77
# 3                Aceite de oliva virgen extra Hacendado           5.63
# 6                          Aceite de oliva 1º Hacendado           4.77
# 8                      Aceite de oliva virgen Hacendado           5.20
# 9                Aceite de oliva virgen extra Hacendado           2.34
# ...                                                 ...            ...
# 5209                        Zumo pura naranja Hacendado           2.20
# 5212                Zumo de naranja selección Hacendado           2.00
# 5216  Bebida de naranja Hacendado sin azúcares añadidos           1.50
# 5219                           Zumo de tomate Hacendado           1.40
# 5221                          Zumo de manzana Hacendado           1.12
#
# [717 rows x 2 columns]

# %%
df_24 = pd.read_csv("../data/srape-mercadona_2024-03-08.csv")
df_24.head(10)
# Out:
#                    categoria            subcategoria  \
# 0           Agua y refrescos  Isotónico y energético
# 1           Agua y refrescos  Isotónico y energético
# 2  Aceite, especias y salsas   Aceite, vinagre y sal
# 3  Aceite, especias y salsas   Aceite, vinagre y sal
# 4  Aceite, especias y salsas   Aceite, vinagre y sal
# 5  Aceite, especias y salsas   Aceite, vinagre y sal
# 6  Aceite, especias y salsas   Aceite, vinagre y sal
# 7  Aceite, especias y salsas   Aceite, vinagre y sal
# 8  Aceite, especias y salsas   Aceite, vinagre y sal
# 9  Aceite, especias y salsas   Aceite, vinagre y sal
#
#                                          descripcion          unidades  \
# 0                    Bebida isotónica limón Aquarius  8 latas x 330 ml
# 1                    Bebida isotónica limón Aquarius  8 latas x 330 ml
# 2                     Aceite de oliva 0,4º Hacendado       Botella 1 L
# 3             Aceite de oliva virgen extra Hacendado       Garrafa 3 L
# ...

# %% [markdown]
# # TABLA PRODUCT INFO (POR FEHCAS)

# %% [markdown]
# ### Set up SQL connection
# First we load the ".env" file so that we can load the user's secret log in info to SQL.

# %%
password = os.getenv("sql_password")
dbName = 'mercadona'
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
engine
