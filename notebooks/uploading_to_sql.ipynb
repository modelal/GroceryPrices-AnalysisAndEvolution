# %% [markdown]
# # 3. Uploading data to SQL
# This jupyter notebook is designed to upload order history and scraped product information from the Mercadona supermarket's website to SQL and calculates the variations.

# %%
# Import necesary libraries
import pandas as pd
import pymysql
import sqlalchemy as alch
from dotenv import load_dotenv
import os

# %% [markdown]
# ### Set up SQL connection
# First we load the ".env" file so that we can load the user's secret log in info to SQL.

# %%
load_dotenv()
# Out:
# True

# %%
password = os.getenv("sql_password")
dbName = 'mercadona'
connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/mercadona)

# %% [markdown]
# ### Load the data
# Now that our connection is set up, we load the scraped product information and the order history retreived from the Mercadona website.
#
# #### Scraping data

# %%
scraping_data = pd.read_csv('../mercadona/scraping/scraping_output/Mercadona Scraping 2023-03-11_21-39-33.csv', sep="~")
scraping_data["product_category"] = scraping_data["product_category"].str.replace(" >","")
scraping_data["product_price_per_unit"] = scraping_data["product_price_per_unit"].str.replace("|","").str.replace(".","")
scraping_data.head(2)
# Out:
# /var/folders/zt/x4f866fn6v5b11fyl7jzdnk80000gn/T/ipykernel_74043/316872866.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   scraping_data["product_price_per_unit"] = scraping_data["product_price_per_unit"].str.replace("|","").str.replace(".","")
#                           product product_type product_volume  \
# 0  Aceite de oliva 0,4º Hacendado      Garrafa            5 L
# 1  Aceite de oliva 0,4º Hacendado      Botella            1 L
#
#   product_price_per_unit  product_price product_unit  \
# 0              4,726 €/L          23.63         /ud.
# 1               4,77 €/L           4.77         /ud.
#
#             product_category    product_subcategory  \
# 0  Aceite, especias y salsas  Aceite, vinagre y sal
# 1  Aceite, especias y salsas  Aceite, vinagre y sal
#
#                                          product_url  product_code  \
# 0  https://tienda.mercadona.es/product/4241/aceit...        4241.0
# 1  https://tienda.mercadona.es/product/4240/aceit...        4240.0
#
#           collected_timestamp
# 0  2023-03-11 21:46:34.649336
# 1  2023-03-11 21:46:35.305827

# %% [markdown]
# #### Order history data

# %%
order_history = pd.read_csv('../mercadona/order_history/outputs/order_history.csv', sep="~", index_col=0)
order_history.head(2)
# Out:
#                                              product  units  price  \
# 0                                        Tomate pera      2   0.60
# 1  Hummus de garbanzos Hacendado con pimiento del...      1   1.45
#
#    order_number       fecha  product_code  price_per_unit
# 0      13996475  2023-03-18         69912            0.30
# 1      13996475  2023-03-18         80862            1.45

# %% [markdown]
# ### Uploading to SQL
# With our data loaded into Pandas DataFrames, we can now use SQLAlchemy to upload it to SQL using our previously set up connection.
#
# #### Upload Scraped data
# Each dataset is uploaded to its own table in the "mercadona" schema. This table is uploaded to the "scraping" table.

# %%
scraping_data.to_sql(name='scraping', con=engine, if_exists='replace', index=False)
# Out:
# 5229

# %% [markdown]
# #### Upload Order History
# Upload the Order History to the "order_history" table in the "mercadona" schema.

# %%
order_history.to_sql(name='order_history', con=engine, if_exists='replace', index=False)
# Out:
# 861

# %% [markdown]
# ### Querying the tables
# Now that our data is uploaded to our SQL server, we can query the tables to calculate the product price variation:

# %%
variations = pd.read_sql_query(
"""
SELECT	oh.product AS product,
		oh.product_code AS product_code,
        s.product_category AS category,
        s.product_subcategory AS subcategory,
        MIN(oh.price_per_unit) AS min,
        MAX(oh.price_per_unit) AS max,
        ROUND(((MAX(oh.price_per_unit)-MIN(oh.price_per_unit))/MIN(oh.price_per_unit))*100,2) AS var
FROM order_history AS oh
JOIN scraping AS s
	ON oh.product_code = s.product_code
WHERE oh.product_code NOT IN(3682, 69912, 3824, 69310, 69320, 69079, 69089, 3132, 69099, 2831, 3858, 3527)
GROUP BY oh.product, oh.product_code, category, subcategory
HAVING var > 0
ORDER BY var DESC
;
"""
, engine)
variations
# Out:
#                                               product  product_code  \
# 0             Acondicionador Repara & Protege Pantene         35615
# 1                    Preparado de carne picada vacuno          3454
# 2                       Café molido natural Hacendado         11178
# 3                       Café molido natural Hacendado         11172
# 4      Muesli Crunchy Hacendado sin azúcares añadidos          9451
# 5            Preparado de carne picada vacuno y cerdo          3453
# 6   Pudding +Proteínas caramelo Hacendado 12 g pro...         60956
# 7                           Champiñón laminado limpio         69519
# 8           Muesli Crunchy Hacendado con frutos secos          9357
# 9              Aceite de oliva virgen extra Hacendado          4718
# 10                       Refresco Coca-Cola Zero Zero         26997
# 11                        Helado almendrado Hacendado         64000
# 12                             Espárrago verde grueso         69643
# 13                Queso de oveja Entrepinares lonchas         50151
# 14                  Tacos de vacuno añojo para guisar          2807
# 15                              Salsa césar Hacendado         17366
# 16                               Palitos de zanahoria         69877
# 17              Leche desnatada sin lactosa Hacendado         10731
# 18          Pimientos tricolor rojo, amarillo y verde         69491
# 19                     Refresco Coca-Cola Zero azúcar         27426
# 20                Filetes pechuga de pollo corte fino          3400
# 21                                   Huevos grandes L         31003
# 22                                Judía verde redonda         69878
# 23                          Remolacha cocida y pelada         69523
# 24       Arroz de secreto ibérico con setas Hacendado         22767
# 25                Ensalada mezcla brotes tiernos maxi         69810
# 26  Espárrago verde troceado Hacendado ultracongelado         61238
# 27          Cebolla troceada Hacendado ultracongelada         13568
# 28        Salteado de setas Hacendado ultracongeladas         61025
# 29                                            Patatas         69166
# 30                                          Arándanos          5501
# 31                              Pollo asado Hacendado         13706
# 32     Pimiento rojo y verde Hacendado ultracongelado         35221
# 33                 Bebida de almendras zero Hacendado         23926
# 34  Medallones preparado de solomillo cerdo provenzal          4152
# 35             Papel higiénico húmedo WC Bosque Verde         47291
# 36                                Spaghetti Hacendado          6331
# 37                  Maxi tortillas de trigo Hacendado         80870
# 38                   Jamón serrano Incarlopsa lonchas         59124
# 39                      Mantequilla con sal Hacendado         20727
# 40                    Queso Cheddar Hacendado lonchas         55017
#
#                        category                            subcategory   min  \
# 0           Cuidado del cabello            Acondicionador y mascarilla  3.00
# 1                         Carne                 Hamburguesas y picadas  6.18
# 2      Cacao, café e infusiones                 Café molido y en grano  2.70
# 3      Cacao, café e infusiones                 Café molido y en grano  2.70
# 4           Cereales y galletas                               Cereales  1.65
# 5                         Carne                 Hamburguesas y picadas  5.74
# 6             Postres y yogures               Gelatina y otros postres  1.70
# 7               Fruta y verdura                                Verdura  1.50
# 8           Cereales y galletas                               Cereales  1.75
# 9     Aceite, especias y salsas                  Aceite, vinagre y sal  2.15
# 10             Agua y refrescos                       Refresco de cola  8.64
# 11                   Congelados                                Helados  2.20
# 12              Fruta y verdura                                Verdura  2.99
# 13         Charcutería y quesos  Queso lonchas, rallado y en porciones  2.23
# 14                        Carne                                 Vacuno  5.47
# 15    Aceite, especias y salsas                           Otras salsas  1.25
# 16              Fruta y verdura                                Verdura  1.60
# 17  Huevos, leche y mantequilla              Leche y bebidas vegetales  0.91
# 18              Fruta y verdura                                Verdura  1.64
# 19             Agua y refrescos                       Refresco de cola  8.64
# 20                        Carne                           Aves y pollo  4.19
# 21  Huevos, leche y mantequilla                                 Huevos  3.95
# 22              Fruta y verdura                                Verdura  2.15
# 23              Fruta y verdura                                Verdura  0.80
# 24   Pizzas y platos preparados            Platos preparados calientes  2.85
# 25              Fruta y verdura           Lechuga y ensalada preparada  1.68
# 26                   Congelados                                Verdura  2.40
# 27                   Congelados                                Verdura  0.96
# 28                   Congelados                                Verdura  1.73
# 29              Fruta y verdura                                Verdura  4.23
# 30              Fruta y verdura                                  Fruta  2.78
# 31   Pizzas y platos preparados            Platos preparados calientes  6.55
# 32                   Congelados                                Verdura  1.06
# 33  Huevos, leche y mantequilla              Leche y bebidas vegetales  1.40
# 34                        Carne                                  Cerdo  3.51
# 35    Cuidado facial y corporal                       Cuidado corporal  1.50
# 36     Arroz, legumbres y pasta                         Pasta y fideos  1.20
# 37       Panadería y pastelería    Pan de molde y otras especialidades  1.55
# 38         Charcutería y quesos                          Jamón serrano  3.49
# 39  Huevos, leche y mantequilla                Mantequilla y margarina  2.10
# 40         Charcutería y quesos  Queso lonchas, rallado y en porciones  1.90
#
#      max    var
# 0   3.80  26.67
# 1   7.45  20.55
# 2   3.20  18.52
# 3   3.20  18.52
# 4   1.95  18.18
# 5   6.70  16.72
# 6   1.95  14.71
# 7   1.72  14.67
# 8   2.00  14.29
# 9   2.45  13.95
# 10  9.84  13.89
# 11  2.50  13.64
# 12  3.39  13.38
# 13  2.52  13.00
# 14  6.16  12.61
# 15  1.40  12.00
# 16  1.78  11.25
# 17  1.01  10.99
# 18  1.79   9.15
# 19  9.36   8.33
# 20  4.51   7.64
# 21  4.25   7.59
# 22  2.29   6.51
# 23  0.85   6.25
# 24  3.00   5.26
# 25  1.75   4.17
# 26  2.50   4.17
# 27  1.00   4.17
# 28  1.80   4.05
# 29  4.40   4.02
# 30  2.89   3.96
# 31  6.80   3.82
# 32  1.10   3.77
# 33  1.45   3.57
# 34  3.63   3.42
# 35  1.55   3.33
# 36  1.24   3.33
# 37  1.60   3.23
# 38  3.58   2.58
# 39  2.15   2.38
# 40  1.92   1.05

# %% [markdown]
# ### Exporting variation data
# With this newly created table we can export the data to a CSV to visualize it:

# %%
variations.to_csv('outputs/variations.csv', sep="~")

# %% [markdown]
# Finally, through these 3 Jupyter notebooks we obtained 3 CSV files that Tableau can use to visualize.
