# %%
import os


import pandas as pd
import numpy as np

# %%
cd historico-facturas-pdf
# Out:
# [Errno 2] No such file or directory: 'historico-facturas-pdf'
# /Users/Moni/Ironhack/my_ironhack/projects/final-project/data/historico-facturas-pdf

# %%
df = pd.read_csv("order_history.csv",delimiter="~")

# %%
df
# Out:
#      Unnamed: 0                                            product  units  \
# 0             0                                        Tomate pera      2
# 1             1  Hummus de garbanzos Hacendado con pimiento del...      1
# 2             2            Acondicionador Repara & Protege Pantene      1
# 3             3                               Palitos de zanahoria      1
# 4             4                           Fajitas pollo y verduras      3
# ..          ...                                                ...    ...
# 665         854                          Pechugas enteras de pollo      1
# 666         856                          Pechugas enteras de pollo      1
# 667         858               Medallones pechuga de pollo marinado      1
# 668         859                                          Aguacates      1
# 669         860                                          Aguacates      1
#
#      price  order_number       fecha  product_code  price_per_unit
# ...

# %%
df = df[["product", "units", "price", "price_per_unit", "fecha", "order_number"]]

# %%
df.rename(columns={"product", "units", "price", "price_per_unit", "fecha", "order_number"})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 670 entries, 0 to 669
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product         670 non-null    object
#  1   units           670 non-null    int64
#  2   price           670 non-null    float64
#  3   price_per_unit  670 non-null    float64
#  4   fecha           670 non-null    object
#  5   order_number    670 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 31.5+ KB

# %%
df = [["description", "units", "price_eu", "unit_price", "date", "order_num"]]
