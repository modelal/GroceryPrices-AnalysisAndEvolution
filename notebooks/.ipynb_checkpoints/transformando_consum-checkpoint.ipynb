# %%
import pandas as pd
import numpy as np
import csv
import re

#Deberia revisar lo de Counter que lo uso bastante y no conoxco muy bien la libreria
from collections import Counter

# %%
def format_price(x):
    
    """
    Decompose and fromate values for the colum price
    
    input: string 
    output: lsit, values of each key already casted:
        price: pos[0]: float
        descuento: pos[1]: float/np.nan(float) (where there is a discount or not)
    
    """
    
    # 1. Replace the € simbol and splits by the "/" ch -- generates a list of 2 elements (nums - text)
    x = x.replace("€", "").replace(",", ".").split("\n")
    
    # 4. Extracts and formats price value:
    price = float(x[0])
    
    # 5. Extracts and formats discount_price if not dicount np.nan
    discount = [np.nan if len(x) == 1 else float(x[1])][0]
    
    return [price, discount]

# %%
ls
# Out:
# Untitled.ipynb                   scrape_dia/
# Untitled1.ipynb                  scrape_mercadona.ipynb
# Untitled2.ipynb                  transformando_consum.ipynb
# scrape_consum.ipynb              transformando_merca.ipynb
# scrape_consum_error-hadle.ipynb

# %%
cons = pd.read_csv("../data/scrape-consum_2024-03-10.csv")
df = cons

# %%
df.head(40)
# Out:
#    categoria               subcategoria  \
# 0   Despensa  Aperitivos y frutos secos
# 1   Despensa  Aperitivos y frutos secos
# 2   Despensa  Aperitivos y frutos secos
# 3   Despensa  Aperitivos y frutos secos
# 4   Despensa  Aperitivos y frutos secos
# 5   Despensa  Aperitivos y frutos secos
# 6   Despensa  Aperitivos y frutos secos
# 7   Despensa  Aperitivos y frutos secos
# 8   Despensa  Aperitivos y frutos secos
# 9   Despensa  Aperitivos y frutos secos
# 10  Despensa  Aperitivos y frutos secos
# 11  Despensa  Aperitivos y frutos secos
# 12  Despensa  Aperitivos y frutos secos
# 13  Despensa  Aperitivos y frutos secos
# 14  Despensa  Aperitivos y frutos secos
# 15  Despensa  Aperitivos y frutos secos
# 16  Despensa  Aperitivos y frutos secos
# 17  Despensa  Aperitivos y frutos secos
# 18  Despensa  Aperitivos y frutos secos
# 19  Despensa  Aperitivos y frutos secos
# 20  Despensa  Aperitivos y frutos secos
# 21  Despensa  Aperitivos y frutos secos
# 22  Despensa  Aperitivos y frutos secos
# 23  Despensa  Aperitivos y frutos secos
# 24  Despensa  Aperitivos y frutos secos
# 25  Despensa  Aperitivos y frutos secos
# 26  Despensa  Aperitivos y frutos secos
# 27  Despensa  Aperitivos y frutos secos
# 28  Despensa  Aperitivos y frutos secos
# 29  Despensa  Aperitivos y frutos secos
# 30  Despensa  Aperitivos y frutos secos
# 31  Despensa  Aperitivos y frutos secos
# 32  Despensa  Aperitivos y frutos secos
# 33  Despensa  Aperitivos y frutos secos
# 34  Despensa  Aperitivos y frutos secos
# 35  Despensa  Aperitivos y frutos secos
# 36  Despensa  Aperitivos y frutos secos
# 37  Despensa  Aperitivos y frutos secos
# 38  Despensa  Aperitivos y frutos secos
# 39  Despensa  Aperitivos y frutos secos
#
#                                     descripcion        unidades  \
# 0        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 1        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 2        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 3        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 4        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 5        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 6        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 7        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 8        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 9        Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 10       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 11       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 12       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 13       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 14       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 15       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 16       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 17       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 18       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 19       Aceitunas Negras sin Hueso Lata 150 Gr   7,93 € / 1 Kg
# 20  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 21  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 22  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 23  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 24  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 25  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 26  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 27  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 28  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 29  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 30  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 31  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 32  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 33  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 34  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 35  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 36  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 37  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 38  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
# 39  Patatas Fritas Lisas Churrería Bolsa 150 Gr  11,67 € / 1 Kg
#
#             precio      marca
# 0   1,29 €\n1,19 €     CONSUM
# 1   1,29 €\n1,19 €     CONSUM
# 2   1,29 €\n1,19 €     CONSUM
# 3   1,29 €\n1,19 €     CONSUM
# 4   1,29 €\n1,19 €     CONSUM
# 5   1,29 €\n1,19 €     CONSUM
# 6   1,29 €\n1,19 €     CONSUM
# 7   1,29 €\n1,19 €     CONSUM
# 8   1,29 €\n1,19 €     CONSUM
# 9   1,29 €\n1,19 €     CONSUM
# 10  1,29 €\n1,19 €     CONSUM
# 11  1,29 €\n1,19 €     CONSUM
# 12  1,29 €\n1,19 €     CONSUM
# 13  1,29 €\n1,19 €     CONSUM
# 14  1,29 €\n1,19 €     CONSUM
# 15  1,29 €\n1,19 €     CONSUM
# 16  1,29 €\n1,19 €     CONSUM
# 17  1,29 €\n1,19 €     CONSUM
# 18  1,29 €\n1,19 €     CONSUM
# 19  1,29 €\n1,19 €     CONSUM
# 20          1,75 €  SANTA ANA
# 21          1,75 €  SANTA ANA
# 22          1,75 €  SANTA ANA
# 23          1,75 €  SANTA ANA
# 24          1,75 €  SANTA ANA
# 25          1,75 €  SANTA ANA
# 26          1,75 €  SANTA ANA
# 27          1,75 €  SANTA ANA
# 28          1,75 €  SANTA ANA
# 29          1,75 €  SANTA ANA
# 30          1,75 €  SANTA ANA
# 31          1,75 €  SANTA ANA
# 32          1,75 €  SANTA ANA
# 33          1,75 €  SANTA ANA
# 34          1,75 €  SANTA ANA
# 35          1,75 €  SANTA ANA
# 36          1,75 €  SANTA ANA
# 37          1,75 €  SANTA ANA
# 38          1,75 €  SANTA ANA
# 39          1,75 €  SANTA ANA

# %%
df.sample()

#categoria, subcategoria y descripcion - las dejamos como están.

# %%
# All collumns have values. 
df.info()

# %%
df["precio"].str.replace("€", "").str.replace(",", ".").str.split("\n")

# %%
  
    # 1. Replace the € simbol and splits by the "/" ch -- generates a list of 2 elements (nums - text)
    x = x.replace("€", "").split("\n1")

# %% [markdown]
# ### Precio
#
# - No hay valores nulos
#
# - El precio puede contener o 2 informaciones o 3:
#     - El precio y a que hace referencia ese precio (pack)
#     - El precio, precio si esta descontado y a que hace referencia ese precio(pack)
#
# - Creamos una funcion que aplicamos a todos los elementos de la columna precio para formaterla. Aqui extraeremos los tres valores comentados antes. Cuando no haya descuento --> np.nan
#     - price_info --> string
#     - price_eu and price_disc_eu --> float
#
#   **Note:** Interesante aqui el tema de apply(function) y luego el lambda.
#
# - Eliminamos la columna original
#
# **NOTE:** En price_info, los valores son bastante consistentes siendo la mayoria de valoes (ud/pack). No obstante hay 14 valores que son de tipo ( xxx g) ej 500 g. Veremos a ver que hacemos. si los descartamos o como los tranformamos. No son una parte muy relevante del conjunto de datos ( 14 de 5035) pero tener en cuenta que hay que revisarlo:

# %% [markdown]
# **Tranform Price column**

# %%
# Apply the function and get the element for each colum: 
df["price_eu"] = df["precio"].apply(format_price).apply(lambda x:x[0])
df["price_disc_eu"] = df["precio"].apply(format_price).apply(lambda x:x[1])

#Drop old column:
df.drop("precio", axis=1, inplace=True)

df.sample()
# Out:
#      categoria subcategoria                  descripcion        unidades  \
# 4905   Frescos   Pescadería  Perlas de Arenque MSC 50 Gr  69,80 € / 1 Kg
#
#          marca  price_eu  price_disc_eu
# 4905  SPHERIKA      3.49            NaN

# %% [markdown]
# ### UNIDADES:

# %%
df
# Out:
#      categoria               subcategoria  \
# 0     Despensa  Aperitivos y frutos secos
# 1     Despensa  Aperitivos y frutos secos
# 2     Despensa  Aperitivos y frutos secos
# 3     Despensa  Aperitivos y frutos secos
# 4     Despensa  Aperitivos y frutos secos
# ...        ...                        ...
# 9449     Bazar                      Velas
# 9450     Bazar                      Velas
# 9451     Bazar                      Velas
# 9452     Bazar                      Velas
# 9453     Bazar                      Velas
#
#                                   descripcion       unidades   marca  \
# 0      Aceitunas Negras sin Hueso Lata 150 Gr  7,93 € / 1 Kg  CONSUM
# 1      Aceitunas Negras sin Hueso Lata 150 Gr  7,93 € / 1 Kg  CONSUM
# 2      Aceitunas Negras sin Hueso Lata 150 Gr  7,93 € / 1 Kg  CONSUM
# 3      Aceitunas Negras sin Hueso Lata 150 Gr  7,93 € / 1 Kg  CONSUM
# 4      Aceitunas Negras sin Hueso Lata 150 Gr  7,93 € / 1 Kg  CONSUM
# ...                                       ...            ...     ...
# 9449  Vaso Satinado Perfumado Pink Flower 1 U   1,95 € / 1 U   ROURA
# 9450  Vaso Satinado Perfumado Pink Flower 1 U   1,95 € / 1 U   ROURA
# 9451  Vaso Satinado Perfumado Pink Flower 1 U   1,95 € / 1 U   ROURA
# 9452  Vaso Satinado Perfumado Pink Flower 1 U   1,95 € / 1 U   ROURA
# 9453  Vaso Satinado Perfumado Pink Flower 1 U   1,95 € / 1 U   ROURA
#
#       price_eu  price_disc_eu
# 0         1.29           1.19
# 1         1.29           1.19
# 2         1.29           1.19
# 3         1.29           1.19
# 4         1.29           1.19
# ...        ...            ...
# 9449      1.95            NaN
# 9450      1.95            NaN
# 9451      1.95            NaN
# 9452      1.95            NaN
# 9453      1.95            NaN
#
# [9454 rows x 7 columns]

# %%
df["unidades"] = df["unidades"].str.replace("aprox.", "")

# %%
lista = df["unidades"].unique()
len(lista)
# Out:
# 1396

# %%
lista
re_words = ["x", "aprox." "(g", "g)", "g", "ud.", "ml", "kg", "ml", "L", "ml)", "(250"]
numb = 30
words = []

words_list = [ i.strip().split(" ") for i in lista]

for i in words_list:
    for e in i:
        if e.isdigit() == False and e not in re_words:
            words.append(e)
            
word_counts = Counter(words)
    
most_common_words = word_counts.most_common(numb)

palabras = [i[0] for i in most_common_words]

# %%
print(palabras)
# Out:
# ['Paquete', 'Caja', 'aprox.', 'Pieza', 'Bote', 'Bandeja', 'Tarro', 'escurrido)', 'paquetes', 'Botella', 'Tarrina', 'cápsulas', 'latas', 'escurrido', 'sobres', 'Lata', 'lavados', 'botellas', 'raciones', 'Spray', 'bolsitas', 'Tubo', 'Bol', 'rebanadas', '(240', 'mini', '(200', 'barritas', 'Sobre', '1,5']

# %%
f_df = df[df['unidades'].str.contains('Paquete')]

# %%
Paquete = i_df["unidades"].tolist()

# %%
def texto_csv(df, column):
    
    #name of the document: as column_name_column.csv
    path = f'column_{column}.csv'
    
    """ Hay que quitar los vacios primero - lo he sacado de la funcion
    por no tranformar la tabla aqui """
   
    #2. We write every colum as a new line in the .csv
    non_empty_values = [str(i) for i in df[column]]
    
    with open(path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows([[value] for value in non_empty_values]) 
        
    print(f'Column successfully exported to {path}')

# %%
texto_csv(df, "descripcion")
# Out:
# Column successfully exported to column_descripcion.csv
