# %%
import os


import pandas as pd
import numpy as np

# %%
def export_to_csv(data_frame, file_name):
    """
    Export a DataFrame to a CSV file.

    Parameters:
        - data_frame: pandas DataFrame
        - file_name: str, name of the CSV file (without the extension)
    """
    #print date stamp - datetime.datetime.now()
    
    #t_stamp = str(datetime.datetime.now()).split(".")[0].replace(" ","_")
    
    file_path = f"{file_name}.csv"
    
    data_frame.to_csv(file_path, index=False)
    print(f"DataFrame successfully exported to {file_path}")

# %%
df = pd.read_csv("../data/historico-facturas-pdf/order_history-kike.csv",delimiter="~")

# %%
df
# Out:
#      Unnamed: 0                                            product  units  \
# 0             0                                        Tomate pera      2
# 1             1  Hummus de garbanzos Hacendado con pimiento del...      1
# 2             2            Acondicionador Repara & Protege Pantene      1
# 3             3                               Palitos de zanahoria      1
# 4             4                           Fajitas pollo y verduras      3
# ..          ...                                                ...    ...
# 665         854                          Pechugas enteras de pollo      1
# 666         856                          Pechugas enteras de pollo      1
# 667         858               Medallones pechuga de pollo marinado      1
# 668         859                                          Aguacates      1
# 669         860                                          Aguacates      1
#
#      price  order_number       fecha  product_code  price_per_unit
# ...

# %%
df = df[["product", "units", "price", "price_per_unit", "fecha", "order_number"]]

# %%
df.rename(columns={"product":"description", "price":"price_eu", "price_per_unit" :"unit_price", "fecha" :"date", "order_number": "order_num"}, inplace=True)
# Out:
# /var/folders/k4/q8g97p495cx7f63kbs0wzyc00000gn/T/ipykernel_12375/1936634914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"product":"description", "price":"price_eu", "price_per_unit" :"unit_price", "fecha" :"date", "order_number": "order_num"}, inplace=True)

# %%
df["order_num"] = df["order_num"].astype(str)
# Out:
# /var/folders/k4/q8g97p495cx7f63kbs0wzyc00000gn/T/ipykernel_12375/3215212593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["order_num"] = df["order_num"].astype(str)

# %%
df
# Out:
#                                            description  units  price_eu  \
# 0                                          Tomate pera      2      0.60
# 1    Hummus de garbanzos Hacendado con pimiento del...      1      1.45
# 2              Acondicionador Repara & Protege Pantene      1      3.80
# 3                                 Palitos de zanahoria      1      1.78
# 4                             Fajitas pollo y verduras      3     11.97
# ..                                                 ...    ...       ...
# 665                          Pechugas enteras de pollo      1      4.32
# 666                          Pechugas enteras de pollo      1      4.40
# 667               Medallones pechuga de pollo marinado      1      4.32
# 668                                          Aguacates      1      2.90
# 669                                          Aguacates      1      3.03
#
#      unit_price        date order_num
# 0          0.30  2023-03-18  13996475
# ...

# %%
export_to_csv(df,"../data/history-pruchase-kike")
# Out:
# DataFrame successfully exported to ../data/history-pruchase-kike.csv
